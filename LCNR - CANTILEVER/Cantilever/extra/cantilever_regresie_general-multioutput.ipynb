# %%
import logging; logging.basicConfig(level=logging.INFO)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import logictensornetworks as ltn
import pandas as pd

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training_sectiune/tot.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
df_comp = df.sample(50) # un numar de valori random sa vedem acuratetea
#df.sample(5)
#df.shape
df = df.sample(int(len(df)*(100/100)))
print(df.shape)
# Out:
# (36573, 11)

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# #df = scaler.fit_transform(df)

# %%
df.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df.shape
# Out:
# Null values in dataset are 0
# (36573, 11)

# %%
df_comp.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df_comp.replace([np.inf, -np.inf], np.nan, inplace=True)
df_comp.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df_comp.shape
# Out:
# Null values in dataset are 0
# (50, 11)

# %%
from sklearn.model_selection import train_test_split


x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Pozitie','Severitate def', 'Severitate inc.']]

x_comp = df_comp[['Severitate def', 'Severitate inc.','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y_comp = df_comp[['Pozitie']]


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2)

#x_comp_train, x_comp_test, y_comp_train, y_comp_test = train_test_split(x_comp, y_comp, test_size=.2)

# %%
batch_size= 64
ds_train = tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(batch_size)
ds_test = tf.data.Dataset.from_tensor_slices((x_test,y_test)).batch(batch_size)

#ds_comp_train = tf.data.Dataset.from_tensor_slices((x_comp_train,y_comp_train)).batch(batch_size)
ds_comp_test = tf.data.Dataset.from_tensor_slices((x_comp,y_comp)).batch(batch_size)
# Out:
# Metal device set to: Apple M1
# 2022-06-10 16:33:30.368639: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-10 16:33:30.368723: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#df['Freq 1    f1 [Hz]'] = df['Freq 1    f1 [Hz]'].astype(float, errors = 'raise')
df.dtypes
# Out:
# Pozitie            float64
# Severitate def     float64
# Severitate inc.    float64
# Mod 1              float64
# Mod 2              float64
# Mod 3              float64
# Mod 4              float64
# Mod 5              float64
# Mod 6              float64
# Mod 7              float64
# Mod 8              float64
# dtype: object

# %%
f = ltn.Function.MLP(input_shapes=[8],output_shape=[3],hidden_layer_sizes=(100,100,50))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.78550
# 2022-06-10 16:33:31.142097: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-10 16:33:31.142151: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train, 
        ds_test, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 60

modelul = train(
    EPOCHS,
    metrics_dict,
    ds_train,
    ds_test,
    train_step,
    test_step,
    csv_path="testtest.csv",
    track_metrics=1
)
# Out:
# 2022-06-10 16:33:31.354122: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-10 16:33:36.623392: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-10 16:33:36.801164: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-10 16:33:37.274506: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.9075, test_sat: 0.9146, train_accuracy: 0.1265, test_accuracy: 0.1155
# Epoch 1, train_sat: 0.9273, test_sat: 0.9217, train_accuracy: 0.0976, test_accuracy: 0.1046
# Epoch 2, train_sat: 0.9351, test_sat: 0.9234, train_accuracy: 0.0871, test_accuracy: 0.1007
# Epoch 3, train_sat: 0.9392, test_sat: 0.9395, train_accuracy: 0.0816, test_accuracy: 0.0795
# Epoch 4, train_sat: 0.9432, test_sat: 0.9430, train_accuracy: 0.0763, test_accuracy: 0.0746
# Epoch 5, train_sat: 0.9465, test_sat: 0.9371, train_accuracy: 0.0719, test_accuracy: 0.0817
# Epoch 6, train_sat: 0.9474, test_sat: 0.9402, train_accuracy: 0.0707, test_accuracy: 0.0805
# Epoch 7, train_sat: 0.9498, test_sat: 0.9449, train_accuracy: 0.0677, test_accuracy: 0.0721
# Epoch 8, train_sat: 0.9492, test_sat: 0.9472, train_accuracy: 0.0684, test_accuracy: 0.0704
# Epoch 9, train_sat: 0.9511, test_sat: 0.9413, train_accuracy: 0.0663, test_accuracy: 0.0780
# Epoch 10, train_sat: 0.9508, test_sat: 0.9417, train_accuracy: 0.0667, test_accuracy: 0.0775
# Epoch 11, train_sat: 0.9522, test_sat: 0.9403, train_accuracy: 0.0648, test_accuracy: 0.0801
# Epoch 12, train_sat: 0.9529, test_sat: 0.9495, train_accuracy: 0.0635, test_accuracy: 0.0653
# Epoch 13, train_sat: 0.9541, test_sat: 0.9533, train_accuracy: 0.0624, test_accuracy: 0.0608
# Epoch 14, train_sat: 0.9541, test_sat: 0.9338, train_accuracy: 0.0624, test_accuracy: 0.0876
# Epoch 15, train_sat: 0.9541, test_sat: 0.9472, train_accuracy: 0.0625, test_accuracy: 0.0695
# Epoch 16, train_sat: 0.9556, test_sat: 0.9406, train_accuracy: 0.0603, test_accuracy: 0.0804
# Epoch 17, train_sat: 0.9573, test_sat: 0.9385, train_accuracy: 0.0579, test_accuracy: 0.0814
# Epoch 18, train_sat: 0.9576, test_sat: 0.9428, train_accuracy: 0.0577, test_accuracy: 0.0760
# Epoch 19, train_sat: 0.9577, test_sat: 0.9474, train_accuracy: 0.0570, test_accuracy: 0.0706
# Epoch 20, train_sat: 0.9583, test_sat: 0.9441, train_accuracy: 0.0564, test_accuracy: 0.0745
# Epoch 21, train_sat: 0.9577, test_sat: 0.9516, train_accuracy: 0.0577, test_accuracy: 0.0633
# Epoch 22, train_sat: 0.9589, test_sat: 0.9475, train_accuracy: 0.0553, test_accuracy: 0.0692
# Epoch 23, train_sat: 0.9571, test_sat: 0.9438, train_accuracy: 0.0586, test_accuracy: 0.0708
# Epoch 24, train_sat: 0.9598, test_sat: 0.9396, train_accuracy: 0.0544, test_accuracy: 0.0800
# Epoch 25, train_sat: 0.9596, test_sat: 0.9490, train_accuracy: 0.0546, test_accuracy: 0.0654
# Epoch 26, train_sat: 0.9598, test_sat: 0.9171, train_accuracy: 0.0546, test_accuracy: 0.1186
# Epoch 27, train_sat: 0.9609, test_sat: 0.9544, train_accuracy: 0.0528, test_accuracy: 0.0598
# Epoch 28, train_sat: 0.9629, test_sat: 0.9483, train_accuracy: 0.0501, test_accuracy: 0.0663
# Epoch 29, train_sat: 0.9635, test_sat: 0.9628, train_accuracy: 0.0492, test_accuracy: 0.0479
# Epoch 30, train_sat: 0.9626, test_sat: 0.9479, train_accuracy: 0.0501, test_accuracy: 0.0685
# Epoch 31, train_sat: 0.9622, test_sat: 0.9519, train_accuracy: 0.0509, test_accuracy: 0.0668
# Epoch 32, train_sat: 0.9626, test_sat: 0.9507, train_accuracy: 0.0502, test_accuracy: 0.0635
# Epoch 33, train_sat: 0.9615, test_sat: 0.9438, train_accuracy: 0.0521, test_accuracy: 0.0757
# Epoch 34, train_sat: 0.9625, test_sat: 0.9618, train_accuracy: 0.0509, test_accuracy: 0.0491
# Epoch 35, train_sat: 0.9651, test_sat: 0.9599, train_accuracy: 0.0471, test_accuracy: 0.0524
# Epoch 36, train_sat: 0.9637, test_sat: 0.9381, train_accuracy: 0.0496, test_accuracy: 0.0794
# Epoch 37, train_sat: 0.9618, test_sat: 0.9602, train_accuracy: 0.0520, test_accuracy: 0.0531
# Epoch 38, train_sat: 0.9646, test_sat: 0.9335, train_accuracy: 0.0470, test_accuracy: 0.0874
# Epoch 39, train_sat: 0.9557, test_sat: 0.9584, train_accuracy: 0.0594, test_accuracy: 0.0525
# Epoch 40, train_sat: 0.9638, test_sat: 0.9474, train_accuracy: 0.0481, test_accuracy: 0.0681
# Epoch 41, train_sat: 0.9606, test_sat: 0.9526, train_accuracy: 0.0529, test_accuracy: 0.0604
# Epoch 42, train_sat: 0.9638, test_sat: 0.9634, train_accuracy: 0.0483, test_accuracy: 0.0460
# Epoch 43, train_sat: 0.9623, test_sat: 0.9618, train_accuracy: 0.0509, test_accuracy: 0.0511
# Epoch 44, train_sat: 0.9663, test_sat: 0.9530, train_accuracy: 0.0451, test_accuracy: 0.0609
# Epoch 45, train_sat: 0.9626, test_sat: 0.9493, train_accuracy: 0.0503, test_accuracy: 0.0664
# Epoch 46, train_sat: 0.9660, test_sat: 0.9520, train_accuracy: 0.0455, test_accuracy: 0.0635
# Epoch 47, train_sat: 0.9577, test_sat: 0.9411, train_accuracy: 0.0572, test_accuracy: 0.0770
# Epoch 48, train_sat: 0.9627, test_sat: 0.9665, train_accuracy: 0.0502, test_accuracy: 0.0431
# Epoch 49, train_sat: 0.9632, test_sat: 0.9666, train_accuracy: 0.0494, test_accuracy: 0.0453
# Epoch 50, train_sat: 0.9606, test_sat: 0.9359, train_accuracy: 0.0526, test_accuracy: 0.0836
# Epoch 51, train_sat: 0.9588, test_sat: 0.9527, train_accuracy: 0.0553, test_accuracy: 0.0629
# Epoch 52, train_sat: 0.9619, test_sat: 0.9424, train_accuracy: 0.0509, test_accuracy: 0.0756
# Epoch 53, train_sat: 0.9627, test_sat: 0.9508, train_accuracy: 0.0506, test_accuracy: 0.0640
# Epoch 54, train_sat: 0.9666, test_sat: 0.9598, train_accuracy: 0.0443, test_accuracy: 0.0502
# Epoch 55, train_sat: 0.9670, test_sat: 0.9653, train_accuracy: 0.0441, test_accuracy: 0.0441
# Epoch 56, train_sat: 0.9659, test_sat: 0.9514, train_accuracy: 0.0461, test_accuracy: 0.0612
# Epoch 57, train_sat: 0.9628, test_sat: 0.9437, train_accuracy: 0.0499, test_accuracy: 0.0738
# Epoch 58, train_sat: 0.9668, test_sat: 0.9527, train_accuracy: 0.0443, test_accuracy: 0.0606
# Epoch 59, train_sat: 0.9682, test_sat: 0.9586, train_accuracy: 0.0424, test_accuracy: 0.0525

# %%
import seaborn as sns
sns.set(font_scale=1.2)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("LTN_regresie_1_test.pdf")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("LTN_regresie_2_test")
plt.show()

# %%
# figure, axis = plt.subplots(figsize=(12,8))
# x_ax = range(51)
# axis.plot(x_ax, data['y_true'].tail(50), label="Pozitie", color='c')
# axis.plot(x_ax, data['y_pred'].tail(50), label="Pozitie-pred", color='b')
# axis.legend()


# plt.savefig('test.pdf')  
# plt.show()

# %%
# fig, axs = plt.subplots(1,2,figsize=(12,6))
# ax = axs[0]
# data = {'y_pred':[],'y_true':[]}
# for x,y in ds_comp_train:
#     data['y_pred'].extend(f.model(x)[:,0].numpy())
#     data['y_true'].extend(y[:,0].numpy())
# df = pd.DataFrame(data,columns=['y_pred','y_true'])
# ax.set_xlim(0,80)
# ax.set_ylim(0,80)
# sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
#             scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
# ax.plot([0,100],[0,100],color="gray",linestyle="--")
# ax.set_xlabel("Actual y values")
# ax.set_ylabel("Fitted y values")
# ax.set_title("Training Data")

# # ax = axs[1]
# data = {'y_pred':[],'y_true':[]}
# for x,y in ds_comp_test:
#     data['y_pred'].extend(f.model(x)[:,0].numpy())
#     data['y_true'].extend(y[:,0].numpy())
# df = pd.DataFrame(data,columns=['y_pred','y_true'])
# ax.set_ylim(0,80)
# ax.set_xlim(0,80)
# sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
#             scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
# ax.plot([0,100],[0,100],color="gray",linestyle="--")
# ax.set_xlabel("Actual y values")
# ax.set_ylabel("Fitted y values")
# ax.set_title("Test Data")
# plt.tight_layout()
# plt.savefig("LTN_regresie_1.pdf")

# %%
# figure, axis = plt.subplots(figsize=(12,8))
# x_ax = range(50)
# axis.plot(x_ax, data['y_true'], label="Pozitie", color='c')
# axis.plot(x_ax, data['y_pred'], label="Pozitie-pred", color='b')
# axis.legend()


# plt.savefig('test_general.pdf')  
# plt.show()

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training_sectiune/tot.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Pozitie','Severitate def', 'Severitate inc.']]
batch_size= 32
ds_test = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

data = {'y_pred':[],'y_true':[],'def':[],'inc':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
    data['def'].extend(y[:,1].numpy())
    data['inc'].extend(y[:,2].numpy())
data_plot = pd.DataFrame(data,columns=['y_pred','y_true','def','inc'])
#'Severitate def', 'Severitate inc.'

# %%
data_plot.head(4)
# Out:
#      y_pred  y_true       def       inc
# 0  0.967147   0.894  0.005124  0.000000
# 1  1.002100   0.908  0.041025  0.000567
# 2  0.657743   0.608  0.016030  0.001020
# 3  0.846638   0.940  0.000867  0.000413

# %%
data_plot.shape
# Out:
# (36573, 4)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

sns.scatterplot(data=data_plot, x="y_pred", y="y_true", hue="def")
plt.legend(title = 'Severitate def', fontsize='20', title_fontsize='20')
plt.xlabel("Predicted value", size=20)
plt.ylabel("Actual value", size=20)
plt.savefig("def.png")

# %%
sns.scatterplot(data=data_plot, x="y_pred", y="y_true", hue="inc")
plt.legend(title = 'Severitate incastrare', fontsize='20', title_fontsize='20')
plt.xlabel("Predicted value", size=20)
plt.ylabel("Actual value", size=20)
plt.savefig("inc.png")

# %%
data_plot['def'].unique
# Out:
# <bound method Series.unique of 0        0.000413
# 1        0.009694
# 2        0.012365
# 3        0.007348
# 4        0.031469
#            ...
# 36568    0.002448
# 36569    0.029094
# 36570    0.002378
# 36571    0.001828
# 36572    0.000578
# Name: def, Length: 36573, dtype: float64>

# %%
import logging; logging.basicConfig(level=logging.INFO)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import logictensornetworks as ltn
import pandas as pd

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training_sectiune/tot.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
df_comp = df.sample(50) # un numar de valori random sa vedem acuratetea
#df.sample(5)
#df.shape
df = df.sample(int(len(df)*(100/100)))
print(df.shape)
# Out:
# (36573, 11)

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# #df = scaler.fit_transform(df)

# %%
df.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df.shape
# Out:
# Null values in dataset are 0
# (36573, 11)

# %%
df_comp.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df_comp.replace([np.inf, -np.inf], np.nan, inplace=True)
df_comp.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df_comp.shape
# Out:
# Null values in dataset are 0
# (50, 11)

# %%
from sklearn.model_selection import train_test_split


x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Severitate def', 'Severitate inc.','Pozitie']]



x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2)

#x_comp_train, x_comp_test, y_comp_train, y_comp_test = train_test_split(x_comp, y_comp, test_size=.2)

# %%
batch_size= 2000
ds_train = tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(batch_size)
ds_test = tf.data.Dataset.from_tensor_slices((x_test,y_test)).batch(batch_size)

#ds_comp_train = tf.data.Dataset.from_tensor_slices((x_comp_train,y_comp_train)).batch(batch_size)
#ds_comp_test = tf.data.Dataset.from_tensor_slices((x_comp,y_comp)).batch(batch_size)
# Out:
# Metal device set to: Apple M1
# 2022-06-11 20:44:45.517039: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-11 20:44:45.517142: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#df['Freq 1    f1 [Hz]'] = df['Freq 1    f1 [Hz]'].astype(float, errors = 'raise')
df.dtypes
# Out:
# Pozitie            float64
# Severitate def     float64
# Severitate inc.    float64
# Mod 1              float64
# Mod 2              float64
# Mod 3              float64
# Mod 4              float64
# Mod 5              float64
# Mod 6              float64
# Mod 7              float64
# Mod 8              float64
# dtype: object

# %%
f = ltn.Function.MLP(input_shapes=[8],output_shape=[3],hidden_layer_sizes=(100,100,50))

# %%
eq = ltn.Predicate.Lambda(
    lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    #lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.97138
# 2022-06-11 20:44:46.205725: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-11 20:44:46.205776: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train, 
        ds_test, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 2000

modelul = train(
    EPOCHS,
    metrics_dict,
    ds_train,
    ds_test,
    train_step,
    test_step,
    csv_path="testtest.csv",
    track_metrics=1
)
# Out:
# 2022-06-11 20:44:46.396614: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-11 20:44:46.881695: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-11 20:44:47.052316: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-11 20:44:47.156325: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.9844, test_sat: 0.9862, train_accuracy: 0.1832, test_accuracy: 0.1595
# Epoch 1, train_sat: 0.9875, test_sat: 0.9884, train_accuracy: 0.1456, test_accuracy: 0.1342
# Epoch 2, train_sat: 0.9883, test_sat: 0.9885, train_accuracy: 0.1357, test_accuracy: 0.1328
# Epoch 3, train_sat: 0.9886, test_sat: 0.9885, train_accuracy: 0.1322, test_accuracy: 0.1329
# Epoch 4, train_sat: 0.9886, test_sat: 0.9886, train_accuracy: 0.1316, test_accuracy: 0.1316
# Epoch 5, train_sat: 0.9887, test_sat: 0.9887, train_accuracy: 0.1308, test_accuracy: 0.1309
# Epoch 6, train_sat: 0.9888, test_sat: 0.9890, train_accuracy: 0.1291, test_accuracy: 0.1275
# Epoch 7, train_sat: 0.9892, test_sat: 0.9894, train_accuracy: 0.1252, test_accuracy: 0.1226
# Epoch 8, train_sat: 0.9895, test_sat: 0.9893, train_accuracy: 0.1211, test_accuracy: 0.1234
# Epoch 9, train_sat: 0.9897, test_sat: 0.9899, train_accuracy: 0.1197, test_accuracy: 0.1160
# Epoch 10, train_sat: 0.9900, test_sat: 0.9902, train_accuracy: 0.1151, test_accuracy: 0.1133
# Epoch 11, train_sat: 0.9902, test_sat: 0.9901, train_accuracy: 0.1132, test_accuracy: 0.1148
# Epoch 12, train_sat: 0.9904, test_sat: 0.9896, train_accuracy: 0.1105, test_accuracy: 0.1205
# Epoch 13, train_sat: 0.9900, test_sat: 0.9904, train_accuracy: 0.1161, test_accuracy: 0.1109
# Epoch 14, train_sat: 0.9906, test_sat: 0.9911, train_accuracy: 0.1089, test_accuracy: 0.1029
# Epoch 15, train_sat: 0.9904, test_sat: 0.9908, train_accuracy: 0.1119, test_accuracy: 0.1060
# Epoch 16, train_sat: 0.9912, test_sat: 0.9911, train_accuracy: 0.1021, test_accuracy: 0.1029
# Epoch 17, train_sat: 0.9910, test_sat: 0.9912, train_accuracy: 0.1040, test_accuracy: 0.1012
# Epoch 18, train_sat: 0.9914, test_sat: 0.9916, train_accuracy: 0.0991, test_accuracy: 0.0967
# Epoch 19, train_sat: 0.9913, test_sat: 0.9910, train_accuracy: 0.1004, test_accuracy: 0.1037
# Epoch 20, train_sat: 0.9920, test_sat: 0.9915, train_accuracy: 0.0926, test_accuracy: 0.0987
# Epoch 21, train_sat: 0.9916, test_sat: 0.9922, train_accuracy: 0.0976, test_accuracy: 0.0902
# Epoch 22, train_sat: 0.9920, test_sat: 0.9919, train_accuracy: 0.0922, test_accuracy: 0.0939
# Epoch 23, train_sat: 0.9922, test_sat: 0.9916, train_accuracy: 0.0894, test_accuracy: 0.0967
# Epoch 24, train_sat: 0.9913, test_sat: 0.9909, train_accuracy: 0.1004, test_accuracy: 0.1045
# Epoch 25, train_sat: 0.9919, test_sat: 0.9920, train_accuracy: 0.0933, test_accuracy: 0.0922
# Epoch 26, train_sat: 0.9923, test_sat: 0.9921, train_accuracy: 0.0888, test_accuracy: 0.0912
# Epoch 27, train_sat: 0.9922, test_sat: 0.9919, train_accuracy: 0.0894, test_accuracy: 0.0931
# Epoch 28, train_sat: 0.9923, test_sat: 0.9919, train_accuracy: 0.0885, test_accuracy: 0.0937
# Epoch 29, train_sat: 0.9924, test_sat: 0.9921, train_accuracy: 0.0881, test_accuracy: 0.0914
# Epoch 30, train_sat: 0.9924, test_sat: 0.9920, train_accuracy: 0.0875, test_accuracy: 0.0920
# Epoch 31, train_sat: 0.9925, test_sat: 0.9926, train_accuracy: 0.0864, test_accuracy: 0.0852
# Epoch 32, train_sat: 0.9924, test_sat: 0.9923, train_accuracy: 0.0876, test_accuracy: 0.0888
# Epoch 33, train_sat: 0.9925, test_sat: 0.9924, train_accuracy: 0.0862, test_accuracy: 0.0875
# Epoch 34, train_sat: 0.9926, test_sat: 0.9927, train_accuracy: 0.0859, test_accuracy: 0.0839
# Epoch 35, train_sat: 0.9925, test_sat: 0.9927, train_accuracy: 0.0868, test_accuracy: 0.0843
# Epoch 36, train_sat: 0.9926, test_sat: 0.9926, train_accuracy: 0.0858, test_accuracy: 0.0854
# Epoch 37, train_sat: 0.9926, test_sat: 0.9928, train_accuracy: 0.0851, test_accuracy: 0.0829
# Epoch 38, train_sat: 0.9926, test_sat: 0.9928, train_accuracy: 0.0850, test_accuracy: 0.0827
# Epoch 39, train_sat: 0.9926, test_sat: 0.9927, train_accuracy: 0.0858, test_accuracy: 0.0846
# Epoch 40, train_sat: 0.9926, test_sat: 0.9925, train_accuracy: 0.0856, test_accuracy: 0.0867
# Epoch 41, train_sat: 0.9926, test_sat: 0.9928, train_accuracy: 0.0850, test_accuracy: 0.0832
# Epoch 42, train_sat: 0.9927, test_sat: 0.9923, train_accuracy: 0.0838, test_accuracy: 0.0890
# Epoch 43, train_sat: 0.9927, test_sat: 0.9928, train_accuracy: 0.0845, test_accuracy: 0.0825
# Epoch 44, train_sat: 0.9928, test_sat: 0.9928, train_accuracy: 0.0828, test_accuracy: 0.0826
# Epoch 45, train_sat: 0.9927, test_sat: 0.9928, train_accuracy: 0.0847, test_accuracy: 0.0831
# Epoch 46, train_sat: 0.9927, test_sat: 0.9923, train_accuracy: 0.0835, test_accuracy: 0.0891
# Epoch 47, train_sat: 0.9928, test_sat: 0.9929, train_accuracy: 0.0827, test_accuracy: 0.0812
# Epoch 48, train_sat: 0.9928, test_sat: 0.9925, train_accuracy: 0.0824, test_accuracy: 0.0864
# Epoch 49, train_sat: 0.9928, test_sat: 0.9927, train_accuracy: 0.0832, test_accuracy: 0.0835
# Epoch 50, train_sat: 0.9928, test_sat: 0.9925, train_accuracy: 0.0829, test_accuracy: 0.0867
# Epoch 51, train_sat: 0.9928, test_sat: 0.9929, train_accuracy: 0.0827, test_accuracy: 0.0817
# Epoch 52, train_sat: 0.9928, test_sat: 0.9925, train_accuracy: 0.0827, test_accuracy: 0.0868
# Epoch 53, train_sat: 0.9929, test_sat: 0.9930, train_accuracy: 0.0820, test_accuracy: 0.0803
# Epoch 54, train_sat: 0.9929, test_sat: 0.9926, train_accuracy: 0.0812, test_accuracy: 0.0849
# Epoch 55, train_sat: 0.9929, test_sat: 0.9929, train_accuracy: 0.0816, test_accuracy: 0.0822
# Epoch 56, train_sat: 0.9929, test_sat: 0.9927, train_accuracy: 0.0817, test_accuracy: 0.0844
# Epoch 57, train_sat: 0.9930, test_sat: 0.9930, train_accuracy: 0.0811, test_accuracy: 0.0805
# Epoch 58, train_sat: 0.9930, test_sat: 0.9927, train_accuracy: 0.0807, test_accuracy: 0.0837
# Epoch 59, train_sat: 0.9930, test_sat: 0.9929, train_accuracy: 0.0809, test_accuracy: 0.0817
# Epoch 60, train_sat: 0.9929, test_sat: 0.9927, train_accuracy: 0.0813, test_accuracy: 0.0835
# Epoch 61, train_sat: 0.9930, test_sat: 0.9930, train_accuracy: 0.0805, test_accuracy: 0.0805
# Epoch 62, train_sat: 0.9930, test_sat: 0.9928, train_accuracy: 0.0805, test_accuracy: 0.0828
# Epoch 63, train_sat: 0.9930, test_sat: 0.9929, train_accuracy: 0.0803, test_accuracy: 0.0813
# Epoch 64, train_sat: 0.9930, test_sat: 0.9929, train_accuracy: 0.0802, test_accuracy: 0.0816
# Epoch 65, train_sat: 0.9931, test_sat: 0.9930, train_accuracy: 0.0799, test_accuracy: 0.0806
# Epoch 66, train_sat: 0.9931, test_sat: 0.9930, train_accuracy: 0.0799, test_accuracy: 0.0810
# Epoch 67, train_sat: 0.9931, test_sat: 0.9930, train_accuracy: 0.0795, test_accuracy: 0.0808
# Epoch 68, train_sat: 0.9930, test_sat: 0.9931, train_accuracy: 0.0801, test_accuracy: 0.0797
# Epoch 69, train_sat: 0.9932, test_sat: 0.9931, train_accuracy: 0.0788, test_accuracy: 0.0792
# Epoch 70, train_sat: 0.9931, test_sat: 0.9932, train_accuracy: 0.0794, test_accuracy: 0.0789
# Epoch 71, train_sat: 0.9932, test_sat: 0.9931, train_accuracy: 0.0780, test_accuracy: 0.0792
# Epoch 72, train_sat: 0.9931, test_sat: 0.9932, train_accuracy: 0.0797, test_accuracy: 0.0783
# Epoch 73, train_sat: 0.9933, test_sat: 0.9933, train_accuracy: 0.0772, test_accuracy: 0.0774
# Epoch 74, train_sat: 0.9931, test_sat: 0.9931, train_accuracy: 0.0790, test_accuracy: 0.0793
# Epoch 75, train_sat: 0.9933, test_sat: 0.9933, train_accuracy: 0.0777, test_accuracy: 0.0771
# Epoch 76, train_sat: 0.9933, test_sat: 0.9934, train_accuracy: 0.0777, test_accuracy: 0.0760
# Epoch 77, train_sat: 0.9932, test_sat: 0.9930, train_accuracy: 0.0782, test_accuracy: 0.0809
# Epoch 78, train_sat: 0.9932, test_sat: 0.9932, train_accuracy: 0.0785, test_accuracy: 0.0779
# Epoch 79, train_sat: 0.9933, test_sat: 0.9934, train_accuracy: 0.0774, test_accuracy: 0.0760
# Epoch 80, train_sat: 0.9933, test_sat: 0.9934, train_accuracy: 0.0777, test_accuracy: 0.0755
# Epoch 81, train_sat: 0.9933, test_sat: 0.9934, train_accuracy: 0.0771, test_accuracy: 0.0761
# Epoch 82, train_sat: 0.9934, test_sat: 0.9934, train_accuracy: 0.0764, test_accuracy: 0.0763
# Epoch 83, train_sat: 0.9932, test_sat: 0.9930, train_accuracy: 0.0776, test_accuracy: 0.0809
# Epoch 84, train_sat: 0.9930, test_sat: 0.9931, train_accuracy: 0.0808, test_accuracy: 0.0796
# Epoch 85, train_sat: 0.9934, test_sat: 0.9932, train_accuracy: 0.0762, test_accuracy: 0.0779
# Epoch 86, train_sat: 0.9932, test_sat: 0.9929, train_accuracy: 0.0778, test_accuracy: 0.0817
# Epoch 87, train_sat: 0.9931, test_sat: 0.9931, train_accuracy: 0.0792, test_accuracy: 0.0790
# Epoch 88, train_sat: 0.9934, test_sat: 0.9934, train_accuracy: 0.0763, test_accuracy: 0.0764
# Epoch 89, train_sat: 0.9935, test_sat: 0.9931, train_accuracy: 0.0753, test_accuracy: 0.0801
# Epoch 90, train_sat: 0.9935, test_sat: 0.9932, train_accuracy: 0.0745, test_accuracy: 0.0780
# Epoch 91, train_sat: 0.9934, test_sat: 0.9937, train_accuracy: 0.0766, test_accuracy: 0.0727
# Epoch 92, train_sat: 0.9936, test_sat: 0.9936, train_accuracy: 0.0735, test_accuracy: 0.0733
# Epoch 93, train_sat: 0.9935, test_sat: 0.9933, train_accuracy: 0.0747, test_accuracy: 0.0772
# Epoch 94, train_sat: 0.9936, test_sat: 0.9935, train_accuracy: 0.0738, test_accuracy: 0.0748
# Epoch 95, train_sat: 0.9936, test_sat: 0.9934, train_accuracy: 0.0730, test_accuracy: 0.0759
# Epoch 96, train_sat: 0.9933, test_sat: 0.9930, train_accuracy: 0.0774, test_accuracy: 0.0801
# Epoch 97, train_sat: 0.9935, test_sat: 0.9931, train_accuracy: 0.0748, test_accuracy: 0.0792
# Epoch 98, train_sat: 0.9934, test_sat: 0.9936, train_accuracy: 0.0764, test_accuracy: 0.0741
# Epoch 99, train_sat: 0.9936, test_sat: 0.9933, train_accuracy: 0.0741, test_accuracy: 0.0774
# Epoch 100, train_sat: 0.9936, test_sat: 0.9938, train_accuracy: 0.0741, test_accuracy: 0.0710
# Epoch 101, train_sat: 0.9937, test_sat: 0.9934, train_accuracy: 0.0726, test_accuracy: 0.0758
# Epoch 102, train_sat: 0.9933, test_sat: 0.9936, train_accuracy: 0.0773, test_accuracy: 0.0730
# Epoch 103, train_sat: 0.9939, test_sat: 0.9940, train_accuracy: 0.0702, test_accuracy: 0.0692
# Epoch 104, train_sat: 0.9935, test_sat: 0.9931, train_accuracy: 0.0753, test_accuracy: 0.0790
# Epoch 105, train_sat: 0.9939, test_sat: 0.9939, train_accuracy: 0.0702, test_accuracy: 0.0697
# Epoch 106, train_sat: 0.9933, test_sat: 0.9927, train_accuracy: 0.0771, test_accuracy: 0.0837
# Epoch 107, train_sat: 0.9936, test_sat: 0.9937, train_accuracy: 0.0739, test_accuracy: 0.0729
# Epoch 108, train_sat: 0.9936, test_sat: 0.9939, train_accuracy: 0.0736, test_accuracy: 0.0698
# Epoch 109, train_sat: 0.9938, test_sat: 0.9937, train_accuracy: 0.0716, test_accuracy: 0.0718
# Epoch 110, train_sat: 0.9938, test_sat: 0.9934, train_accuracy: 0.0712, test_accuracy: 0.0763
# Epoch 111, train_sat: 0.9939, test_sat: 0.9935, train_accuracy: 0.0701, test_accuracy: 0.0743
# Epoch 112, train_sat: 0.9937, test_sat: 0.9937, train_accuracy: 0.0722, test_accuracy: 0.0726
# Epoch 113, train_sat: 0.9940, test_sat: 0.9933, train_accuracy: 0.0694, test_accuracy: 0.0775
# Epoch 114, train_sat: 0.9937, test_sat: 0.9940, train_accuracy: 0.0729, test_accuracy: 0.0686
# Epoch 115, train_sat: 0.9937, test_sat: 0.9939, train_accuracy: 0.0724, test_accuracy: 0.0698
# Epoch 116, train_sat: 0.9937, test_sat: 0.9938, train_accuracy: 0.0725, test_accuracy: 0.0714
# Epoch 117, train_sat: 0.9938, test_sat: 0.9931, train_accuracy: 0.0710, test_accuracy: 0.0798
# Epoch 118, train_sat: 0.9939, test_sat: 0.9941, train_accuracy: 0.0701, test_accuracy: 0.0675
# Epoch 119, train_sat: 0.9942, test_sat: 0.9944, train_accuracy: 0.0669, test_accuracy: 0.0647
# Epoch 120, train_sat: 0.9941, test_sat: 0.9941, train_accuracy: 0.0682, test_accuracy: 0.0687
# Epoch 121, train_sat: 0.9943, test_sat: 0.9945, train_accuracy: 0.0660, test_accuracy: 0.0628
# Epoch 122, train_sat: 0.9940, test_sat: 0.9941, train_accuracy: 0.0694, test_accuracy: 0.0679
# Epoch 123, train_sat: 0.9938, test_sat: 0.9942, train_accuracy: 0.0713, test_accuracy: 0.0661
# Epoch 124, train_sat: 0.9940, test_sat: 0.9945, train_accuracy: 0.0696, test_accuracy: 0.0631
# Epoch 125, train_sat: 0.9940, test_sat: 0.9943, train_accuracy: 0.0694, test_accuracy: 0.0659
# Epoch 126, train_sat: 0.9938, test_sat: 0.9936, train_accuracy: 0.0719, test_accuracy: 0.0742
# Epoch 127, train_sat: 0.9941, test_sat: 0.9944, train_accuracy: 0.0687, test_accuracy: 0.0648
# Epoch 128, train_sat: 0.9942, test_sat: 0.9943, train_accuracy: 0.0673, test_accuracy: 0.0655
# Epoch 129, train_sat: 0.9940, test_sat: 0.9936, train_accuracy: 0.0686, test_accuracy: 0.0736
# Epoch 130, train_sat: 0.9941, test_sat: 0.9945, train_accuracy: 0.0683, test_accuracy: 0.0629
# Epoch 131, train_sat: 0.9942, test_sat: 0.9946, train_accuracy: 0.0665, test_accuracy: 0.0620
# Epoch 132, train_sat: 0.9941, test_sat: 0.9938, train_accuracy: 0.0675, test_accuracy: 0.0713
# Epoch 133, train_sat: 0.9944, test_sat: 0.9946, train_accuracy: 0.0647, test_accuracy: 0.0619
# Epoch 134, train_sat: 0.9945, test_sat: 0.9939, train_accuracy: 0.0626, test_accuracy: 0.0700
# Epoch 135, train_sat: 0.9941, test_sat: 0.9946, train_accuracy: 0.0679, test_accuracy: 0.0624
# Epoch 136, train_sat: 0.9943, test_sat: 0.9945, train_accuracy: 0.0657, test_accuracy: 0.0629
# Epoch 137, train_sat: 0.9944, test_sat: 0.9942, train_accuracy: 0.0647, test_accuracy: 0.0666
# Epoch 138, train_sat: 0.9940, test_sat: 0.9947, train_accuracy: 0.0690, test_accuracy: 0.0612
# Epoch 139, train_sat: 0.9943, test_sat: 0.9944, train_accuracy: 0.0660, test_accuracy: 0.0647
# Epoch 140, train_sat: 0.9943, test_sat: 0.9947, train_accuracy: 0.0654, test_accuracy: 0.0612
# Epoch 141, train_sat: 0.9945, test_sat: 0.9944, train_accuracy: 0.0638, test_accuracy: 0.0648
# Epoch 142, train_sat: 0.9945, test_sat: 0.9948, train_accuracy: 0.0630, test_accuracy: 0.0602
# Epoch 143, train_sat: 0.9942, test_sat: 0.9944, train_accuracy: 0.0664, test_accuracy: 0.0642
# Epoch 144, train_sat: 0.9945, test_sat: 0.9944, train_accuracy: 0.0636, test_accuracy: 0.0647
# Epoch 145, train_sat: 0.9941, test_sat: 0.9940, train_accuracy: 0.0678, test_accuracy: 0.0694
# Epoch 146, train_sat: 0.9944, test_sat: 0.9938, train_accuracy: 0.0646, test_accuracy: 0.0712
# Epoch 147, train_sat: 0.9942, test_sat: 0.9941, train_accuracy: 0.0665, test_accuracy: 0.0682
# Epoch 148, train_sat: 0.9945, test_sat: 0.9942, train_accuracy: 0.0631, test_accuracy: 0.0662
# Epoch 149, train_sat: 0.9946, test_sat: 0.9942, train_accuracy: 0.0616, test_accuracy: 0.0669
# Epoch 150, train_sat: 0.9942, test_sat: 0.9947, train_accuracy: 0.0667, test_accuracy: 0.0609
# Epoch 151, train_sat: 0.9945, test_sat: 0.9946, train_accuracy: 0.0634, test_accuracy: 0.0620
# Epoch 152, train_sat: 0.9948, test_sat: 0.9950, train_accuracy: 0.0603, test_accuracy: 0.0578
# Epoch 153, train_sat: 0.9947, test_sat: 0.9946, train_accuracy: 0.0603, test_accuracy: 0.0616
# Epoch 154, train_sat: 0.9948, test_sat: 0.9951, train_accuracy: 0.0594, test_accuracy: 0.0562
# Epoch 155, train_sat: 0.9948, test_sat: 0.9944, train_accuracy: 0.0603, test_accuracy: 0.0642
# Epoch 156, train_sat: 0.9943, test_sat: 0.9934, train_accuracy: 0.0655, test_accuracy: 0.0757
# Epoch 157, train_sat: 0.9945, test_sat: 0.9942, train_accuracy: 0.0631, test_accuracy: 0.0673
# Epoch 158, train_sat: 0.9945, test_sat: 0.9944, train_accuracy: 0.0639, test_accuracy: 0.0638
# Epoch 159, train_sat: 0.9945, test_sat: 0.9949, train_accuracy: 0.0631, test_accuracy: 0.0590
# Epoch 160, train_sat: 0.9945, test_sat: 0.9950, train_accuracy: 0.0631, test_accuracy: 0.0578
# Epoch 161, train_sat: 0.9946, test_sat: 0.9949, train_accuracy: 0.0621, test_accuracy: 0.0590
# Epoch 162, train_sat: 0.9949, test_sat: 0.9949, train_accuracy: 0.0583, test_accuracy: 0.0587
# Epoch 163, train_sat: 0.9947, test_sat: 0.9947, train_accuracy: 0.0605, test_accuracy: 0.0608
# Epoch 164, train_sat: 0.9946, test_sat: 0.9952, train_accuracy: 0.0628, test_accuracy: 0.0553
# Epoch 165, train_sat: 0.9948, test_sat: 0.9952, train_accuracy: 0.0595, test_accuracy: 0.0555
# Epoch 166, train_sat: 0.9944, test_sat: 0.9936, train_accuracy: 0.0645, test_accuracy: 0.0735
# Epoch 167, train_sat: 0.9944, test_sat: 0.9950, train_accuracy: 0.0643, test_accuracy: 0.0578
# Epoch 168, train_sat: 0.9948, test_sat: 0.9951, train_accuracy: 0.0604, test_accuracy: 0.0565
# Epoch 169, train_sat: 0.9946, test_sat: 0.9942, train_accuracy: 0.0628, test_accuracy: 0.0675
# Epoch 170, train_sat: 0.9950, test_sat: 0.9949, train_accuracy: 0.0581, test_accuracy: 0.0580
# Epoch 171, train_sat: 0.9947, test_sat: 0.9950, train_accuracy: 0.0608, test_accuracy: 0.0574
# Epoch 172, train_sat: 0.9947, test_sat: 0.9947, train_accuracy: 0.0609, test_accuracy: 0.0605
# Epoch 173, train_sat: 0.9948, test_sat: 0.9951, train_accuracy: 0.0595, test_accuracy: 0.0563
# Epoch 174, train_sat: 0.9948, test_sat: 0.9946, train_accuracy: 0.0595, test_accuracy: 0.0619
# Epoch 175, train_sat: 0.9947, test_sat: 0.9951, train_accuracy: 0.0608, test_accuracy: 0.0564
# Epoch 176, train_sat: 0.9946, test_sat: 0.9950, train_accuracy: 0.0619, test_accuracy: 0.0570
# Epoch 177, train_sat: 0.9949, test_sat: 0.9950, train_accuracy: 0.0592, test_accuracy: 0.0578
# Epoch 178, train_sat: 0.9948, test_sat: 0.9952, train_accuracy: 0.0602, test_accuracy: 0.0555
# Epoch 179, train_sat: 0.9948, test_sat: 0.9944, train_accuracy: 0.0601, test_accuracy: 0.0643
# Epoch 180, train_sat: 0.9948, test_sat: 0.9947, train_accuracy: 0.0593, test_accuracy: 0.0607
# Epoch 181, train_sat: 0.9949, test_sat: 0.9951, train_accuracy: 0.0589, test_accuracy: 0.0564
# Epoch 182, train_sat: 0.9947, test_sat: 0.9942, train_accuracy: 0.0612, test_accuracy: 0.0669
# Epoch 183, train_sat: 0.9952, test_sat: 0.9950, train_accuracy: 0.0555, test_accuracy: 0.0574
# Epoch 184, train_sat: 0.9950, test_sat: 0.9949, train_accuracy: 0.0582, test_accuracy: 0.0584
# Epoch 185, train_sat: 0.9950, test_sat: 0.9952, train_accuracy: 0.0575, test_accuracy: 0.0550
# Epoch 186, train_sat: 0.9949, test_sat: 0.9950, train_accuracy: 0.0586, test_accuracy: 0.0575
# Epoch 187, train_sat: 0.9950, test_sat: 0.9948, train_accuracy: 0.0580, test_accuracy: 0.0591
# Epoch 188, train_sat: 0.9948, test_sat: 0.9950, train_accuracy: 0.0596, test_accuracy: 0.0568
# Epoch 189, train_sat: 0.9948, test_sat: 0.9937, train_accuracy: 0.0600, test_accuracy: 0.0727
# Epoch 190, train_sat: 0.9951, test_sat: 0.9948, train_accuracy: 0.0557, test_accuracy: 0.0600
# Epoch 191, train_sat: 0.9948, test_sat: 0.9944, train_accuracy: 0.0601, test_accuracy: 0.0650
# Epoch 192, train_sat: 0.9950, test_sat: 0.9950, train_accuracy: 0.0576, test_accuracy: 0.0579
# Epoch 193, train_sat: 0.9950, test_sat: 0.9953, train_accuracy: 0.0574, test_accuracy: 0.0542
# Epoch 194, train_sat: 0.9949, test_sat: 0.9946, train_accuracy: 0.0587, test_accuracy: 0.0629
# Epoch 195, train_sat: 0.9952, test_sat: 0.9950, train_accuracy: 0.0557, test_accuracy: 0.0571
# Epoch 196, train_sat: 0.9949, test_sat: 0.9950, train_accuracy: 0.0585, test_accuracy: 0.0576
# Epoch 197, train_sat: 0.9950, test_sat: 0.9944, train_accuracy: 0.0573, test_accuracy: 0.0644
# Epoch 198, train_sat: 0.9953, test_sat: 0.9951, train_accuracy: 0.0541, test_accuracy: 0.0565
# Epoch 199, train_sat: 0.9949, test_sat: 0.9944, train_accuracy: 0.0583, test_accuracy: 0.0651
# Epoch 200, train_sat: 0.9950, test_sat: 0.9949, train_accuracy: 0.0578, test_accuracy: 0.0588
# Epoch 201, train_sat: 0.9951, test_sat: 0.9952, train_accuracy: 0.0562, test_accuracy: 0.0554
# Epoch 202, train_sat: 0.9949, test_sat: 0.9949, train_accuracy: 0.0589, test_accuracy: 0.0586
# Epoch 203, train_sat: 0.9952, test_sat: 0.9953, train_accuracy: 0.0555, test_accuracy: 0.0546
# Epoch 204, train_sat: 0.9952, test_sat: 0.9954, train_accuracy: 0.0556, test_accuracy: 0.0526
# Epoch 205, train_sat: 0.9952, test_sat: 0.9955, train_accuracy: 0.0554, test_accuracy: 0.0513
# Epoch 206, train_sat: 0.9950, test_sat: 0.9945, train_accuracy: 0.0575, test_accuracy: 0.0630
# Epoch 207, train_sat: 0.9951, test_sat: 0.9954, train_accuracy: 0.0559, test_accuracy: 0.0527
# Epoch 208, train_sat: 0.9950, test_sat: 0.9952, train_accuracy: 0.0578, test_accuracy: 0.0556
# Epoch 209, train_sat: 0.9953, test_sat: 0.9952, train_accuracy: 0.0546, test_accuracy: 0.0551
# Epoch 210, train_sat: 0.9952, test_sat: 0.9954, train_accuracy: 0.0556, test_accuracy: 0.0524
# Epoch 211, train_sat: 0.9950, test_sat: 0.9950, train_accuracy: 0.0575, test_accuracy: 0.0580
# Epoch 212, train_sat: 0.9953, test_sat: 0.9952, train_accuracy: 0.0536, test_accuracy: 0.0546
# Epoch 213, train_sat: 0.9950, test_sat: 0.9952, train_accuracy: 0.0572, test_accuracy: 0.0551
# Epoch 214, train_sat: 0.9950, test_sat: 0.9946, train_accuracy: 0.0571, test_accuracy: 0.0624
# Epoch 215, train_sat: 0.9954, test_sat: 0.9949, train_accuracy: 0.0524, test_accuracy: 0.0580
# Epoch 216, train_sat: 0.9949, test_sat: 0.9948, train_accuracy: 0.0587, test_accuracy: 0.0596
# Epoch 217, train_sat: 0.9952, test_sat: 0.9948, train_accuracy: 0.0552, test_accuracy: 0.0598
# Epoch 218, train_sat: 0.9953, test_sat: 0.9953, train_accuracy: 0.0542, test_accuracy: 0.0539
# Epoch 219, train_sat: 0.9949, test_sat: 0.9947, train_accuracy: 0.0582, test_accuracy: 0.0609
# Epoch 220, train_sat: 0.9953, test_sat: 0.9955, train_accuracy: 0.0539, test_accuracy: 0.0521
# Epoch 221, train_sat: 0.9952, test_sat: 0.9953, train_accuracy: 0.0554, test_accuracy: 0.0541
# Epoch 222, train_sat: 0.9953, test_sat: 0.9954, train_accuracy: 0.0541, test_accuracy: 0.0524
# Epoch 223, train_sat: 0.9952, test_sat: 0.9948, train_accuracy: 0.0552, test_accuracy: 0.0596
# Epoch 224, train_sat: 0.9952, test_sat: 0.9948, train_accuracy: 0.0549, test_accuracy: 0.0592
# Epoch 225, train_sat: 0.9953, test_sat: 0.9954, train_accuracy: 0.0542, test_accuracy: 0.0530
# Epoch 226, train_sat: 0.9951, test_sat: 0.9950, train_accuracy: 0.0567, test_accuracy: 0.0577
# Epoch 227, train_sat: 0.9955, test_sat: 0.9951, train_accuracy: 0.0519, test_accuracy: 0.0565
# Epoch 228, train_sat: 0.9951, test_sat: 0.9955, train_accuracy: 0.0566, test_accuracy: 0.0515
# Epoch 229, train_sat: 0.9953, test_sat: 0.9953, train_accuracy: 0.0538, test_accuracy: 0.0542
# Epoch 230, train_sat: 0.9955, test_sat: 0.9954, train_accuracy: 0.0518, test_accuracy: 0.0533
# Epoch 231, train_sat: 0.9951, test_sat: 0.9953, train_accuracy: 0.0562, test_accuracy: 0.0538
# Epoch 232, train_sat: 0.9955, test_sat: 0.9954, train_accuracy: 0.0525, test_accuracy: 0.0526
# Epoch 233, train_sat: 0.9951, test_sat: 0.9943, train_accuracy: 0.0562, test_accuracy: 0.0666
# Epoch 234, train_sat: 0.9950, test_sat: 0.9942, train_accuracy: 0.0570, test_accuracy: 0.0679
# Epoch 235, train_sat: 0.9949, test_sat: 0.9938, train_accuracy: 0.0585, test_accuracy: 0.0714
# Epoch 236, train_sat: 0.9938, test_sat: 0.9931, train_accuracy: 0.0731, test_accuracy: 0.0786
# Epoch 237, train_sat: 0.9939, test_sat: 0.9952, train_accuracy: 0.0708, test_accuracy: 0.0545
# Epoch 238, train_sat: 0.9950, test_sat: 0.9949, train_accuracy: 0.0576, test_accuracy: 0.0587
# Epoch 239, train_sat: 0.9953, test_sat: 0.9954, train_accuracy: 0.0543, test_accuracy: 0.0522
# Epoch 240, train_sat: 0.9953, test_sat: 0.9946, train_accuracy: 0.0543, test_accuracy: 0.0624
# Epoch 241, train_sat: 0.9954, test_sat: 0.9954, train_accuracy: 0.0522, test_accuracy: 0.0531
# Epoch 242, train_sat: 0.9953, test_sat: 0.9956, train_accuracy: 0.0545, test_accuracy: 0.0501
# Epoch 243, train_sat: 0.9953, test_sat: 0.9951, train_accuracy: 0.0537, test_accuracy: 0.0570
# Epoch 244, train_sat: 0.9956, test_sat: 0.9956, train_accuracy: 0.0503, test_accuracy: 0.0502
# Epoch 245, train_sat: 0.9953, test_sat: 0.9955, train_accuracy: 0.0543, test_accuracy: 0.0518
# Epoch 246, train_sat: 0.9952, test_sat: 0.9944, train_accuracy: 0.0548, test_accuracy: 0.0645
# Epoch 247, train_sat: 0.9957, test_sat: 0.9952, train_accuracy: 0.0497, test_accuracy: 0.0547
# Epoch 248, train_sat: 0.9951, test_sat: 0.9951, train_accuracy: 0.0562, test_accuracy: 0.0566
# Epoch 249, train_sat: 0.9951, test_sat: 0.9945, train_accuracy: 0.0566, test_accuracy: 0.0639
# Epoch 250, train_sat: 0.9952, test_sat: 0.9948, train_accuracy: 0.0554, test_accuracy: 0.0600
# Epoch 251, train_sat: 0.9954, test_sat: 0.9954, train_accuracy: 0.0523, test_accuracy: 0.0530
# Epoch 252, train_sat: 0.9952, test_sat: 0.9953, train_accuracy: 0.0554, test_accuracy: 0.0539
# Epoch 253, train_sat: 0.9956, test_sat: 0.9957, train_accuracy: 0.0508, test_accuracy: 0.0491
# Epoch 254, train_sat: 0.9952, test_sat: 0.9948, train_accuracy: 0.0551, test_accuracy: 0.0595
# Epoch 255, train_sat: 0.9957, test_sat: 0.9957, train_accuracy: 0.0489, test_accuracy: 0.0490
# Epoch 256, train_sat: 0.9955, test_sat: 0.9956, train_accuracy: 0.0514, test_accuracy: 0.0499
# Epoch 257, train_sat: 0.9953, test_sat: 0.9951, train_accuracy: 0.0536, test_accuracy: 0.0566
# Epoch 258, train_sat: 0.9953, test_sat: 0.9952, train_accuracy: 0.0544, test_accuracy: 0.0556
# Epoch 259, train_sat: 0.9952, test_sat: 0.9946, train_accuracy: 0.0551, test_accuracy: 0.0618
# Epoch 260, train_sat: 0.9957, test_sat: 0.9957, train_accuracy: 0.0488, test_accuracy: 0.0495
# Epoch 261, train_sat: 0.9957, test_sat: 0.9951, train_accuracy: 0.0495, test_accuracy: 0.0558
# Epoch 262, train_sat: 0.9953, test_sat: 0.9956, train_accuracy: 0.0538, test_accuracy: 0.0507
# Epoch 263, train_sat: 0.9955, test_sat: 0.9959, train_accuracy: 0.0521, test_accuracy: 0.0472
# Epoch 264, train_sat: 0.9953, test_sat: 0.9954, train_accuracy: 0.0543, test_accuracy: 0.0527
# Epoch 265, train_sat: 0.9959, test_sat: 0.9956, train_accuracy: 0.0474, test_accuracy: 0.0497
# Epoch 266, train_sat: 0.9954, test_sat: 0.9956, train_accuracy: 0.0524, test_accuracy: 0.0507
# Epoch 267, train_sat: 0.9955, test_sat: 0.9955, train_accuracy: 0.0513, test_accuracy: 0.0510
# Epoch 268, train_sat: 0.9957, test_sat: 0.9957, train_accuracy: 0.0498, test_accuracy: 0.0493
# Epoch 269, train_sat: 0.9951, test_sat: 0.9943, train_accuracy: 0.0564, test_accuracy: 0.0654
# Epoch 270, train_sat: 0.9957, test_sat: 0.9959, train_accuracy: 0.0494, test_accuracy: 0.0468
# Epoch 271, train_sat: 0.9954, test_sat: 0.9953, train_accuracy: 0.0528, test_accuracy: 0.0538
# Epoch 272, train_sat: 0.9954, test_sat: 0.9952, train_accuracy: 0.0534, test_accuracy: 0.0549
# Epoch 273, train_sat: 0.9952, test_sat: 0.9945, train_accuracy: 0.0552, test_accuracy: 0.0633
# Epoch 274, train_sat: 0.9948, test_sat: 0.9956, train_accuracy: 0.0608, test_accuracy: 0.0502
# Epoch 275, train_sat: 0.9954, test_sat: 0.9953, train_accuracy: 0.0535, test_accuracy: 0.0537
# Epoch 276, train_sat: 0.9956, test_sat: 0.9954, train_accuracy: 0.0498, test_accuracy: 0.0523
# Epoch 277, train_sat: 0.9954, test_sat: 0.9958, train_accuracy: 0.0534, test_accuracy: 0.0479
# Epoch 278, train_sat: 0.9954, test_sat: 0.9959, train_accuracy: 0.0531, test_accuracy: 0.0476
# Epoch 279, train_sat: 0.9958, test_sat: 0.9954, train_accuracy: 0.0480, test_accuracy: 0.0526
# Epoch 280, train_sat: 0.9955, test_sat: 0.9951, train_accuracy: 0.0519, test_accuracy: 0.0557
# Epoch 281, train_sat: 0.9952, test_sat: 0.9941, train_accuracy: 0.0550, test_accuracy: 0.0680
# Epoch 282, train_sat: 0.9955, test_sat: 0.9960, train_accuracy: 0.0515, test_accuracy: 0.0463
# Epoch 283, train_sat: 0.9954, test_sat: 0.9957, train_accuracy: 0.0537, test_accuracy: 0.0496
# Epoch 284, train_sat: 0.9946, test_sat: 0.9954, train_accuracy: 0.0628, test_accuracy: 0.0529
# Epoch 285, train_sat: 0.9955, test_sat: 0.9953, train_accuracy: 0.0518, test_accuracy: 0.0548
# Epoch 286, train_sat: 0.9957, test_sat: 0.9953, train_accuracy: 0.0493, test_accuracy: 0.0534
# Epoch 287, train_sat: 0.9954, test_sat: 0.9957, train_accuracy: 0.0531, test_accuracy: 0.0486
# Epoch 288, train_sat: 0.9954, test_sat: 0.9959, train_accuracy: 0.0527, test_accuracy: 0.0465
# Epoch 289, train_sat: 0.9956, test_sat: 0.9953, train_accuracy: 0.0505, test_accuracy: 0.0537
# Epoch 290, train_sat: 0.9958, test_sat: 0.9953, train_accuracy: 0.0484, test_accuracy: 0.0540
# Epoch 291, train_sat: 0.9955, test_sat: 0.9952, train_accuracy: 0.0522, test_accuracy: 0.0553
# Epoch 292, train_sat: 0.9957, test_sat: 0.9960, train_accuracy: 0.0491, test_accuracy: 0.0458
# Epoch 293, train_sat: 0.9952, test_sat: 0.9943, train_accuracy: 0.0554, test_accuracy: 0.0654
# Epoch 294, train_sat: 0.9951, test_sat: 0.9953, train_accuracy: 0.0566, test_accuracy: 0.0545
# Epoch 295, train_sat: 0.9956, test_sat: 0.9955, train_accuracy: 0.0509, test_accuracy: 0.0510
# Epoch 296, train_sat: 0.9955, test_sat: 0.9958, train_accuracy: 0.0523, test_accuracy: 0.0486
# Epoch 297, train_sat: 0.9956, test_sat: 0.9950, train_accuracy: 0.0503, test_accuracy: 0.0575
# Epoch 298, train_sat: 0.9958, test_sat: 0.9960, train_accuracy: 0.0480, test_accuracy: 0.0453
# Epoch 299, train_sat: 0.9956, test_sat: 0.9961, train_accuracy: 0.0510, test_accuracy: 0.0443
# Epoch 300, train_sat: 0.9957, test_sat: 0.9959, train_accuracy: 0.0499, test_accuracy: 0.0473
# Epoch 301, train_sat: 0.9953, test_sat: 0.9945, train_accuracy: 0.0538, test_accuracy: 0.0631
# Epoch 302, train_sat: 0.9955, test_sat: 0.9961, train_accuracy: 0.0520, test_accuracy: 0.0442
# Epoch 303, train_sat: 0.9956, test_sat: 0.9962, train_accuracy: 0.0511, test_accuracy: 0.0442
# Epoch 304, train_sat: 0.9953, test_sat: 0.9948, train_accuracy: 0.0541, test_accuracy: 0.0597
# Epoch 305, train_sat: 0.9955, test_sat: 0.9956, train_accuracy: 0.0514, test_accuracy: 0.0501
# Epoch 306, train_sat: 0.9959, test_sat: 0.9949, train_accuracy: 0.0469, test_accuracy: 0.0592
# Epoch 307, train_sat: 0.9951, test_sat: 0.9960, train_accuracy: 0.0573, test_accuracy: 0.0460
# Epoch 308, train_sat: 0.9953, test_sat: 0.9945, train_accuracy: 0.0544, test_accuracy: 0.0629
# Epoch 309, train_sat: 0.9954, test_sat: 0.9955, train_accuracy: 0.0525, test_accuracy: 0.0508
# Epoch 310, train_sat: 0.9957, test_sat: 0.9956, train_accuracy: 0.0495, test_accuracy: 0.0497
# Epoch 311, train_sat: 0.9954, test_sat: 0.9961, train_accuracy: 0.0528, test_accuracy: 0.0449
# Epoch 312, train_sat: 0.9950, test_sat: 0.9953, train_accuracy: 0.0573, test_accuracy: 0.0536
# Epoch 313, train_sat: 0.9958, test_sat: 0.9955, train_accuracy: 0.0479, test_accuracy: 0.0520
# Epoch 314, train_sat: 0.9957, test_sat: 0.9962, train_accuracy: 0.0499, test_accuracy: 0.0430
# Epoch 315, train_sat: 0.9954, test_sat: 0.9944, train_accuracy: 0.0533, test_accuracy: 0.0645
# Epoch 316, train_sat: 0.9950, test_sat: 0.9948, train_accuracy: 0.0576, test_accuracy: 0.0601
# Epoch 317, train_sat: 0.9953, test_sat: 0.9957, train_accuracy: 0.0547, test_accuracy: 0.0490
# Epoch 318, train_sat: 0.9958, test_sat: 0.9960, train_accuracy: 0.0487, test_accuracy: 0.0453
# Epoch 319, train_sat: 0.9958, test_sat: 0.9952, train_accuracy: 0.0485, test_accuracy: 0.0556
# Epoch 320, train_sat: 0.9961, test_sat: 0.9953, train_accuracy: 0.0445, test_accuracy: 0.0539
# Epoch 321, train_sat: 0.9947, test_sat: 0.9953, train_accuracy: 0.0618, test_accuracy: 0.0535
# Epoch 322, train_sat: 0.9957, test_sat: 0.9956, train_accuracy: 0.0493, test_accuracy: 0.0508
# Epoch 323, train_sat: 0.9956, test_sat: 0.9956, train_accuracy: 0.0510, test_accuracy: 0.0507
# Epoch 324, train_sat: 0.9957, test_sat: 0.9958, train_accuracy: 0.0492, test_accuracy: 0.0482
# Epoch 325, train_sat: 0.9960, test_sat: 0.9962, train_accuracy: 0.0465, test_accuracy: 0.0436
# Epoch 326, train_sat: 0.9961, test_sat: 0.9952, train_accuracy: 0.0449, test_accuracy: 0.0550
# Epoch 327, train_sat: 0.9940, test_sat: 0.9943, train_accuracy: 0.0696, test_accuracy: 0.0654
# Epoch 328, train_sat: 0.9950, test_sat: 0.9951, train_accuracy: 0.0577, test_accuracy: 0.0555
# Epoch 329, train_sat: 0.9955, test_sat: 0.9953, train_accuracy: 0.0514, test_accuracy: 0.0535
# Epoch 330, train_sat: 0.9955, test_sat: 0.9954, train_accuracy: 0.0514, test_accuracy: 0.0523
# Epoch 331, train_sat: 0.9956, test_sat: 0.9951, train_accuracy: 0.0509, test_accuracy: 0.0571
# Epoch 332, train_sat: 0.9960, test_sat: 0.9953, train_accuracy: 0.0456, test_accuracy: 0.0541
# Epoch 333, train_sat: 0.9938, test_sat: 0.9941, train_accuracy: 0.0717, test_accuracy: 0.0674
# Epoch 334, train_sat: 0.9948, test_sat: 0.9955, train_accuracy: 0.0602, test_accuracy: 0.0520
# Epoch 335, train_sat: 0.9957, test_sat: 0.9958, train_accuracy: 0.0494, test_accuracy: 0.0476
# Epoch 336, train_sat: 0.9959, test_sat: 0.9951, train_accuracy: 0.0472, test_accuracy: 0.0564
# Epoch 337, train_sat: 0.9957, test_sat: 0.9958, train_accuracy: 0.0495, test_accuracy: 0.0479
# Epoch 338, train_sat: 0.9952, test_sat: 0.9948, train_accuracy: 0.0557, test_accuracy: 0.0595
# Epoch 339, train_sat: 0.9950, test_sat: 0.9945, train_accuracy: 0.0579, test_accuracy: 0.0629
# Epoch 340, train_sat: 0.9953, test_sat: 0.9950, train_accuracy: 0.0540, test_accuracy: 0.0571
# Epoch 341, train_sat: 0.9948, test_sat: 0.9950, train_accuracy: 0.0603, test_accuracy: 0.0572
# Epoch 342, train_sat: 0.9950, test_sat: 0.9956, train_accuracy: 0.0587, test_accuracy: 0.0502
# Epoch 343, train_sat: 0.9958, test_sat: 0.9958, train_accuracy: 0.0487, test_accuracy: 0.0477
# Epoch 344, train_sat: 0.9961, test_sat: 0.9961, train_accuracy: 0.0450, test_accuracy: 0.0443
# Epoch 345, train_sat: 0.9955, test_sat: 0.9943, train_accuracy: 0.0523, test_accuracy: 0.0658
# Epoch 346, train_sat: 0.9954, test_sat: 0.9963, train_accuracy: 0.0528, test_accuracy: 0.0426
# Epoch 347, train_sat: 0.9958, test_sat: 0.9958, train_accuracy: 0.0489, test_accuracy: 0.0480
# Epoch 348, train_sat: 0.9959, test_sat: 0.9965, train_accuracy: 0.0479, test_accuracy: 0.0404
# Epoch 349, train_sat: 0.9959, test_sat: 0.9959, train_accuracy: 0.0472, test_accuracy: 0.0477
# Epoch 350, train_sat: 0.9962, test_sat: 0.9956, train_accuracy: 0.0439, test_accuracy: 0.0506
# Epoch 351, train_sat: 0.9961, test_sat: 0.9957, train_accuracy: 0.0454, test_accuracy: 0.0495
# Epoch 352, train_sat: 0.9957, test_sat: 0.9965, train_accuracy: 0.0495, test_accuracy: 0.0402
# Epoch 353, train_sat: 0.9955, test_sat: 0.9949, train_accuracy: 0.0520, test_accuracy: 0.0578
# Epoch 354, train_sat: 0.9958, test_sat: 0.9961, train_accuracy: 0.0478, test_accuracy: 0.0450
# Epoch 355, train_sat: 0.9961, test_sat: 0.9957, train_accuracy: 0.0454, test_accuracy: 0.0488
# Epoch 356, train_sat: 0.9953, test_sat: 0.9953, train_accuracy: 0.0546, test_accuracy: 0.0544
# Epoch 357, train_sat: 0.9957, test_sat: 0.9954, train_accuracy: 0.0497, test_accuracy: 0.0531
# Epoch 358, train_sat: 0.9961, test_sat: 0.9959, train_accuracy: 0.0443, test_accuracy: 0.0474
# Epoch 359, train_sat: 0.9947, test_sat: 0.9935, train_accuracy: 0.0616, test_accuracy: 0.0748
# Epoch 360, train_sat: 0.9953, test_sat: 0.9961, train_accuracy: 0.0549, test_accuracy: 0.0445
# Epoch 361, train_sat: 0.9959, test_sat: 0.9963, train_accuracy: 0.0472, test_accuracy: 0.0420
# Epoch 362, train_sat: 0.9959, test_sat: 0.9948, train_accuracy: 0.0470, test_accuracy: 0.0604
# Epoch 363, train_sat: 0.9950, test_sat: 0.9949, train_accuracy: 0.0577, test_accuracy: 0.0590
# Epoch 364, train_sat: 0.9957, test_sat: 0.9959, train_accuracy: 0.0494, test_accuracy: 0.0470
# Epoch 365, train_sat: 0.9957, test_sat: 0.9952, train_accuracy: 0.0487, test_accuracy: 0.0557
# Epoch 366, train_sat: 0.9963, test_sat: 0.9955, train_accuracy: 0.0419, test_accuracy: 0.0517
# Epoch 367, train_sat: 0.9951, test_sat: 0.9954, train_accuracy: 0.0580, test_accuracy: 0.0531
# Epoch 368, train_sat: 0.9960, test_sat: 0.9960, train_accuracy: 0.0459, test_accuracy: 0.0460
# Epoch 369, train_sat: 0.9960, test_sat: 0.9957, train_accuracy: 0.0458, test_accuracy: 0.0491
# Epoch 370, train_sat: 0.9962, test_sat: 0.9958, train_accuracy: 0.0434, test_accuracy: 0.0480
# Epoch 371, train_sat: 0.9962, test_sat: 0.9959, train_accuracy: 0.0442, test_accuracy: 0.0468
# Epoch 372, train_sat: 0.9950, test_sat: 0.9938, train_accuracy: 0.0582, test_accuracy: 0.0709
# Epoch 373, train_sat: 0.9955, test_sat: 0.9962, train_accuracy: 0.0522, test_accuracy: 0.0431
# Epoch 374, train_sat: 0.9963, test_sat: 0.9955, train_accuracy: 0.0426, test_accuracy: 0.0520
# Epoch 375, train_sat: 0.9946, test_sat: 0.9950, train_accuracy: 0.0630, test_accuracy: 0.0574
# Epoch 376, train_sat: 0.9957, test_sat: 0.9961, train_accuracy: 0.0492, test_accuracy: 0.0447
# Epoch 377, train_sat: 0.9959, test_sat: 0.9954, train_accuracy: 0.0474, test_accuracy: 0.0529
# Epoch 378, train_sat: 0.9962, test_sat: 0.9958, train_accuracy: 0.0440, test_accuracy: 0.0475
# Epoch 379, train_sat: 0.9959, test_sat: 0.9965, train_accuracy: 0.0470, test_accuracy: 0.0401
# Epoch 380, train_sat: 0.9959, test_sat: 0.9963, train_accuracy: 0.0472, test_accuracy: 0.0421
# Epoch 381, train_sat: 0.9963, test_sat: 0.9957, train_accuracy: 0.0418, test_accuracy: 0.0489
# Epoch 382, train_sat: 0.9961, test_sat: 0.9960, train_accuracy: 0.0446, test_accuracy: 0.0454
# Epoch 383, train_sat: 0.9959, test_sat: 0.9966, train_accuracy: 0.0474, test_accuracy: 0.0391
# Epoch 384, train_sat: 0.9959, test_sat: 0.9963, train_accuracy: 0.0477, test_accuracy: 0.0423
# Epoch 385, train_sat: 0.9959, test_sat: 0.9951, train_accuracy: 0.0470, test_accuracy: 0.0562
# Epoch 386, train_sat: 0.9955, test_sat: 0.9961, train_accuracy: 0.0530, test_accuracy: 0.0442
# Epoch 387, train_sat: 0.9961, test_sat: 0.9956, train_accuracy: 0.0441, test_accuracy: 0.0501
# Epoch 388, train_sat: 0.9950, test_sat: 0.9954, train_accuracy: 0.0593, test_accuracy: 0.0530
# Epoch 389, train_sat: 0.9958, test_sat: 0.9963, train_accuracy: 0.0482, test_accuracy: 0.0418
# Epoch 390, train_sat: 0.9960, test_sat: 0.9949, train_accuracy: 0.0463, test_accuracy: 0.0592
# Epoch 391, train_sat: 0.9966, test_sat: 0.9964, train_accuracy: 0.0389, test_accuracy: 0.0409
# Epoch 392, train_sat: 0.9965, test_sat: 0.9963, train_accuracy: 0.0408, test_accuracy: 0.0424
# Epoch 393, train_sat: 0.9964, test_sat: 0.9963, train_accuracy: 0.0409, test_accuracy: 0.0416
# Epoch 394, train_sat: 0.9964, test_sat: 0.9960, train_accuracy: 0.0416, test_accuracy: 0.0454
# Epoch 395, train_sat: 0.9962, test_sat: 0.9965, train_accuracy: 0.0435, test_accuracy: 0.0397
# Epoch 396, train_sat: 0.9956, test_sat: 0.9950, train_accuracy: 0.0518, test_accuracy: 0.0577
# Epoch 397, train_sat: 0.9951, test_sat: 0.9945, train_accuracy: 0.0565, test_accuracy: 0.0631
# Epoch 398, train_sat: 0.9958, test_sat: 0.9960, train_accuracy: 0.0490, test_accuracy: 0.0464
# Epoch 399, train_sat: 0.9965, test_sat: 0.9959, train_accuracy: 0.0398, test_accuracy: 0.0468
# Epoch 400, train_sat: 0.9963, test_sat: 0.9960, train_accuracy: 0.0420, test_accuracy: 0.0453
# Epoch 401, train_sat: 0.9951, test_sat: 0.9951, train_accuracy: 0.0569, test_accuracy: 0.0564
# Epoch 402, train_sat: 0.9958, test_sat: 0.9961, train_accuracy: 0.0481, test_accuracy: 0.0448
# Epoch 403, train_sat: 0.9963, test_sat: 0.9960, train_accuracy: 0.0430, test_accuracy: 0.0454
# Epoch 404, train_sat: 0.9963, test_sat: 0.9956, train_accuracy: 0.0423, test_accuracy: 0.0508
# Epoch 405, train_sat: 0.9965, test_sat: 0.9960, train_accuracy: 0.0400, test_accuracy: 0.0461
# Epoch 406, train_sat: 0.9964, test_sat: 0.9965, train_accuracy: 0.0419, test_accuracy: 0.0396
# Epoch 407, train_sat: 0.9955, test_sat: 0.9957, train_accuracy: 0.0529, test_accuracy: 0.0496
# Epoch 408, train_sat: 0.9956, test_sat: 0.9956, train_accuracy: 0.0513, test_accuracy: 0.0506
# Epoch 409, train_sat: 0.9960, test_sat: 0.9964, train_accuracy: 0.0463, test_accuracy: 0.0413
# Epoch 410, train_sat: 0.9961, test_sat: 0.9966, train_accuracy: 0.0451, test_accuracy: 0.0390
# Epoch 411, train_sat: 0.9962, test_sat: 0.9954, train_accuracy: 0.0429, test_accuracy: 0.0526
# Epoch 412, train_sat: 0.9964, test_sat: 0.9968, train_accuracy: 0.0417, test_accuracy: 0.0360
# Epoch 413, train_sat: 0.9958, test_sat: 0.9950, train_accuracy: 0.0490, test_accuracy: 0.0576
# Epoch 414, train_sat: 0.9956, test_sat: 0.9964, train_accuracy: 0.0507, test_accuracy: 0.0408
# Epoch 415, train_sat: 0.9962, test_sat: 0.9960, train_accuracy: 0.0444, test_accuracy: 0.0458
# Epoch 416, train_sat: 0.9965, test_sat: 0.9961, train_accuracy: 0.0393, test_accuracy: 0.0446
# Epoch 417, train_sat: 0.9964, test_sat: 0.9966, train_accuracy: 0.0410, test_accuracy: 0.0389
# Epoch 418, train_sat: 0.9963, test_sat: 0.9968, train_accuracy: 0.0424, test_accuracy: 0.0371
# Epoch 419, train_sat: 0.9963, test_sat: 0.9953, train_accuracy: 0.0422, test_accuracy: 0.0542
# Epoch 420, train_sat: 0.9967, test_sat: 0.9964, train_accuracy: 0.0383, test_accuracy: 0.0410
# Epoch 421, train_sat: 0.9960, test_sat: 0.9950, train_accuracy: 0.0463, test_accuracy: 0.0571
# Epoch 422, train_sat: 0.9962, test_sat: 0.9959, train_accuracy: 0.0439, test_accuracy: 0.0464
# Epoch 423, train_sat: 0.9959, test_sat: 0.9967, train_accuracy: 0.0476, test_accuracy: 0.0377
# Epoch 424, train_sat: 0.9964, test_sat: 0.9966, train_accuracy: 0.0416, test_accuracy: 0.0388
# Epoch 425, train_sat: 0.9966, test_sat: 0.9970, train_accuracy: 0.0396, test_accuracy: 0.0346
# Epoch 426, train_sat: 0.9960, test_sat: 0.9952, train_accuracy: 0.0465, test_accuracy: 0.0551
# Epoch 427, train_sat: 0.9961, test_sat: 0.9957, train_accuracy: 0.0453, test_accuracy: 0.0490
# Epoch 428, train_sat: 0.9962, test_sat: 0.9964, train_accuracy: 0.0445, test_accuracy: 0.0414
# Epoch 429, train_sat: 0.9962, test_sat: 0.9962, train_accuracy: 0.0443, test_accuracy: 0.0433
# Epoch 430, train_sat: 0.9967, test_sat: 0.9957, train_accuracy: 0.0375, test_accuracy: 0.0498
# Epoch 431, train_sat: 0.9962, test_sat: 0.9968, train_accuracy: 0.0443, test_accuracy: 0.0365
# Epoch 432, train_sat: 0.9965, test_sat: 0.9967, train_accuracy: 0.0401, test_accuracy: 0.0381
# Epoch 433, train_sat: 0.9968, test_sat: 0.9958, train_accuracy: 0.0358, test_accuracy: 0.0478
# Epoch 434, train_sat: 0.9942, test_sat: 0.9946, train_accuracy: 0.0678, test_accuracy: 0.0619
# Epoch 435, train_sat: 0.9955, test_sat: 0.9958, train_accuracy: 0.0522, test_accuracy: 0.0476
# Epoch 436, train_sat: 0.9961, test_sat: 0.9960, train_accuracy: 0.0442, test_accuracy: 0.0457
# Epoch 437, train_sat: 0.9964, test_sat: 0.9956, train_accuracy: 0.0408, test_accuracy: 0.0504
# Epoch 438, train_sat: 0.9960, test_sat: 0.9961, train_accuracy: 0.0459, test_accuracy: 0.0443
# Epoch 439, train_sat: 0.9964, test_sat: 0.9969, train_accuracy: 0.0411, test_accuracy: 0.0356
# Epoch 440, train_sat: 0.9968, test_sat: 0.9962, train_accuracy: 0.0367, test_accuracy: 0.0437
# Epoch 441, train_sat: 0.9956, test_sat: 0.9952, train_accuracy: 0.0506, test_accuracy: 0.0552
# Epoch 442, train_sat: 0.9960, test_sat: 0.9964, train_accuracy: 0.0463, test_accuracy: 0.0413
# Epoch 443, train_sat: 0.9963, test_sat: 0.9968, train_accuracy: 0.0425, test_accuracy: 0.0367
# Epoch 444, train_sat: 0.9966, test_sat: 0.9959, train_accuracy: 0.0391, test_accuracy: 0.0466
# Epoch 445, train_sat: 0.9966, test_sat: 0.9961, train_accuracy: 0.0384, test_accuracy: 0.0448
# Epoch 446, train_sat: 0.9949, test_sat: 0.9946, train_accuracy: 0.0594, test_accuracy: 0.0621
# Epoch 447, train_sat: 0.9956, test_sat: 0.9962, train_accuracy: 0.0517, test_accuracy: 0.0436
# Epoch 448, train_sat: 0.9964, test_sat: 0.9965, train_accuracy: 0.0408, test_accuracy: 0.0404
# Epoch 449, train_sat: 0.9969, test_sat: 0.9961, train_accuracy: 0.0349, test_accuracy: 0.0449
# Epoch 450, train_sat: 0.9967, test_sat: 0.9972, train_accuracy: 0.0384, test_accuracy: 0.0321
# Epoch 451, train_sat: 0.9967, test_sat: 0.9957, train_accuracy: 0.0382, test_accuracy: 0.0491
# Epoch 452, train_sat: 0.9966, test_sat: 0.9961, train_accuracy: 0.0390, test_accuracy: 0.0448
# Epoch 453, train_sat: 0.9962, test_sat: 0.9969, train_accuracy: 0.0447, test_accuracy: 0.0355
# Epoch 454, train_sat: 0.9964, test_sat: 0.9960, train_accuracy: 0.0415, test_accuracy: 0.0453
# Epoch 455, train_sat: 0.9967, test_sat: 0.9965, train_accuracy: 0.0379, test_accuracy: 0.0395
# Epoch 456, train_sat: 0.9966, test_sat: 0.9971, train_accuracy: 0.0396, test_accuracy: 0.0325
# Epoch 457, train_sat: 0.9966, test_sat: 0.9957, train_accuracy: 0.0387, test_accuracy: 0.0491
# Epoch 458, train_sat: 0.9968, test_sat: 0.9970, train_accuracy: 0.0371, test_accuracy: 0.0346
# Epoch 459, train_sat: 0.9967, test_sat: 0.9960, train_accuracy: 0.0376, test_accuracy: 0.0456
# Epoch 460, train_sat: 0.9954, test_sat: 0.9950, train_accuracy: 0.0532, test_accuracy: 0.0570
# Epoch 461, train_sat: 0.9961, test_sat: 0.9970, train_accuracy: 0.0449, test_accuracy: 0.0337
# Epoch 462, train_sat: 0.9966, test_sat: 0.9967, train_accuracy: 0.0389, test_accuracy: 0.0383
# Epoch 463, train_sat: 0.9968, test_sat: 0.9966, train_accuracy: 0.0359, test_accuracy: 0.0385
# Epoch 464, train_sat: 0.9961, test_sat: 0.9956, train_accuracy: 0.0463, test_accuracy: 0.0507
# Epoch 465, train_sat: 0.9959, test_sat: 0.9963, train_accuracy: 0.0477, test_accuracy: 0.0424
# Epoch 466, train_sat: 0.9968, test_sat: 0.9960, train_accuracy: 0.0364, test_accuracy: 0.0461
# Epoch 467, train_sat: 0.9963, test_sat: 0.9962, train_accuracy: 0.0432, test_accuracy: 0.0437
# Epoch 468, train_sat: 0.9966, test_sat: 0.9966, train_accuracy: 0.0394, test_accuracy: 0.0390
# Epoch 469, train_sat: 0.9968, test_sat: 0.9971, train_accuracy: 0.0363, test_accuracy: 0.0333
# Epoch 470, train_sat: 0.9965, test_sat: 0.9967, train_accuracy: 0.0402, test_accuracy: 0.0373
# Epoch 471, train_sat: 0.9967, test_sat: 0.9963, train_accuracy: 0.0380, test_accuracy: 0.0425
# Epoch 472, train_sat: 0.9968, test_sat: 0.9957, train_accuracy: 0.0367, test_accuracy: 0.0489
# Epoch 473, train_sat: 0.9950, test_sat: 0.9959, train_accuracy: 0.0592, test_accuracy: 0.0466
# Epoch 474, train_sat: 0.9963, test_sat: 0.9964, train_accuracy: 0.0422, test_accuracy: 0.0410
# Epoch 475, train_sat: 0.9963, test_sat: 0.9962, train_accuracy: 0.0428, test_accuracy: 0.0426
# Epoch 476, train_sat: 0.9958, test_sat: 0.9947, train_accuracy: 0.0487, test_accuracy: 0.0615
# Epoch 477, train_sat: 0.9951, test_sat: 0.9957, train_accuracy: 0.0568, test_accuracy: 0.0489
# Epoch 478, train_sat: 0.9962, test_sat: 0.9966, train_accuracy: 0.0438, test_accuracy: 0.0391
# Epoch 479, train_sat: 0.9965, test_sat: 0.9966, train_accuracy: 0.0405, test_accuracy: 0.0392
# Epoch 480, train_sat: 0.9969, test_sat: 0.9959, train_accuracy: 0.0352, test_accuracy: 0.0464
# Epoch 481, train_sat: 0.9965, test_sat: 0.9969, train_accuracy: 0.0398, test_accuracy: 0.0350
# Epoch 482, train_sat: 0.9960, test_sat: 0.9949, train_accuracy: 0.0467, test_accuracy: 0.0579
# Epoch 483, train_sat: 0.9960, test_sat: 0.9954, train_accuracy: 0.0464, test_accuracy: 0.0530
# Epoch 484, train_sat: 0.9965, test_sat: 0.9967, train_accuracy: 0.0409, test_accuracy: 0.0376
# Epoch 485, train_sat: 0.9969, test_sat: 0.9972, train_accuracy: 0.0354, test_accuracy: 0.0320
# Epoch 486, train_sat: 0.9967, test_sat: 0.9970, train_accuracy: 0.0387, test_accuracy: 0.0342
# Epoch 487, train_sat: 0.9968, test_sat: 0.9972, train_accuracy: 0.0371, test_accuracy: 0.0324
# Epoch 488, train_sat: 0.9960, test_sat: 0.9950, train_accuracy: 0.0466, test_accuracy: 0.0573
# Epoch 489, train_sat: 0.9959, test_sat: 0.9968, train_accuracy: 0.0472, test_accuracy: 0.0369
# Epoch 490, train_sat: 0.9969, test_sat: 0.9957, train_accuracy: 0.0356, test_accuracy: 0.0494
# Epoch 491, train_sat: 0.9967, test_sat: 0.9968, train_accuracy: 0.0376, test_accuracy: 0.0359
# Epoch 492, train_sat: 0.9968, test_sat: 0.9967, train_accuracy: 0.0368, test_accuracy: 0.0376
# Epoch 493, train_sat: 0.9968, test_sat: 0.9967, train_accuracy: 0.0373, test_accuracy: 0.0378
# Epoch 494, train_sat: 0.9968, test_sat: 0.9969, train_accuracy: 0.0368, test_accuracy: 0.0352
# Epoch 495, train_sat: 0.9969, test_sat: 0.9967, train_accuracy: 0.0362, test_accuracy: 0.0379
# Epoch 496, train_sat: 0.9969, test_sat: 0.9969, train_accuracy: 0.0355, test_accuracy: 0.0355
# Epoch 497, train_sat: 0.9967, test_sat: 0.9969, train_accuracy: 0.0385, test_accuracy: 0.0352
# Epoch 498, train_sat: 0.9969, test_sat: 0.9967, train_accuracy: 0.0360, test_accuracy: 0.0375
# Epoch 499, train_sat: 0.9968, test_sat: 0.9965, train_accuracy: 0.0370, test_accuracy: 0.0398
# Epoch 500, train_sat: 0.9969, test_sat: 0.9966, train_accuracy: 0.0361, test_accuracy: 0.0388
# Epoch 501, train_sat: 0.9968, test_sat: 0.9964, train_accuracy: 0.0364, test_accuracy: 0.0414
# Epoch 502, train_sat: 0.9968, test_sat: 0.9968, train_accuracy: 0.0367, test_accuracy: 0.0369
# Epoch 503, train_sat: 0.9968, test_sat: 0.9967, train_accuracy: 0.0367, test_accuracy: 0.0380
# Epoch 504, train_sat: 0.9967, test_sat: 0.9966, train_accuracy: 0.0377, test_accuracy: 0.0391
# ...
# Epoch 1832, train_sat: 0.9981, test_sat: 0.9982, train_accuracy: 0.0216, test_accuracy: 0.0203
# Epoch 1833, train_sat: 0.9982, test_sat: 0.9984, train_accuracy: 0.0202, test_accuracy: 0.0171
# Epoch 1834, train_sat: 0.9983, test_sat: 0.9982, train_accuracy: 0.0189, test_accuracy: 0.0194
# Epoch 1835, train_sat: 0.9984, test_sat: 0.9982, train_accuracy: 0.0182, test_accuracy: 0.0195
# Epoch 1836, train_sat: 0.9977, test_sat: 0.9973, train_accuracy: 0.0272, test_accuracy: 0.0300
# Epoch 1837, train_sat: 0.9980, test_sat: 0.9986, train_accuracy: 0.0244, test_accuracy: 0.0160
# Epoch 1838, train_sat: 0.9980, test_sat: 0.9982, train_accuracy: 0.0228, test_accuracy: 0.0202
# Epoch 1839, train_sat: 0.9979, test_sat: 0.9975, train_accuracy: 0.0243, test_accuracy: 0.0280
# Epoch 1840, train_sat: 0.9977, test_sat: 0.9979, train_accuracy: 0.0259, test_accuracy: 0.0231
# Epoch 1841, train_sat: 0.9981, test_sat: 0.9973, train_accuracy: 0.0214, test_accuracy: 0.0307
# Epoch 1842, train_sat: 0.9971, test_sat: 0.9969, train_accuracy: 0.0347, test_accuracy: 0.0351
# Epoch 1843, train_sat: 0.9970, test_sat: 0.9973, train_accuracy: 0.0344, test_accuracy: 0.0302
# Epoch 1844, train_sat: 0.9976, test_sat: 0.9976, train_accuracy: 0.0273, test_accuracy: 0.0274
# Epoch 1845, train_sat: 0.9980, test_sat: 0.9978, train_accuracy: 0.0221, test_accuracy: 0.0249
# Epoch 1846, train_sat: 0.9982, test_sat: 0.9982, train_accuracy: 0.0203, test_accuracy: 0.0201
# Epoch 1847, train_sat: 0.9980, test_sat: 0.9967, train_accuracy: 0.0222, test_accuracy: 0.0370
# Epoch 1848, train_sat: 0.9973, test_sat: 0.9968, train_accuracy: 0.0328, test_accuracy: 0.0367
# Epoch 1849, train_sat: 0.9976, test_sat: 0.9980, train_accuracy: 0.0277, test_accuracy: 0.0226
# Epoch 1850, train_sat: 0.9980, test_sat: 0.9979, train_accuracy: 0.0225, test_accuracy: 0.0234
# Epoch 1851, train_sat: 0.9979, test_sat: 0.9978, train_accuracy: 0.0238, test_accuracy: 0.0251
# Epoch 1852, train_sat: 0.9982, test_sat: 0.9982, train_accuracy: 0.0211, test_accuracy: 0.0206
# Epoch 1853, train_sat: 0.9980, test_sat: 0.9985, train_accuracy: 0.0227, test_accuracy: 0.0170
# Epoch 1854, train_sat: 0.9980, test_sat: 0.9982, train_accuracy: 0.0230, test_accuracy: 0.0202
# Epoch 1855, train_sat: 0.9982, test_sat: 0.9981, train_accuracy: 0.0198, test_accuracy: 0.0210
# Epoch 1856, train_sat: 0.9982, test_sat: 0.9979, train_accuracy: 0.0208, test_accuracy: 0.0242
# Epoch 1857, train_sat: 0.9975, test_sat: 0.9966, train_accuracy: 0.0298, test_accuracy: 0.0382
# Epoch 1858, train_sat: 0.9959, test_sat: 0.9972, train_accuracy: 0.0498, test_accuracy: 0.0317
# Epoch 1859, train_sat: 0.9972, test_sat: 0.9971, train_accuracy: 0.0321, test_accuracy: 0.0326
# Epoch 1860, train_sat: 0.9978, test_sat: 0.9984, train_accuracy: 0.0255, test_accuracy: 0.0179
# Epoch 1861, train_sat: 0.9980, test_sat: 0.9980, train_accuracy: 0.0230, test_accuracy: 0.0221
# Epoch 1862, train_sat: 0.9982, test_sat: 0.9983, train_accuracy: 0.0199, test_accuracy: 0.0193
# Epoch 1863, train_sat: 0.9983, test_sat: 0.9984, train_accuracy: 0.0187, test_accuracy: 0.0174
# Epoch 1864, train_sat: 0.9984, test_sat: 0.9984, train_accuracy: 0.0184, test_accuracy: 0.0181
# Epoch 1865, train_sat: 0.9983, test_sat: 0.9979, train_accuracy: 0.0193, test_accuracy: 0.0239
# Epoch 1866, train_sat: 0.9969, test_sat: 0.9949, train_accuracy: 0.0365, test_accuracy: 0.0583
# Epoch 1867, train_sat: 0.9965, test_sat: 0.9972, train_accuracy: 0.0415, test_accuracy: 0.0313
# Epoch 1868, train_sat: 0.9978, test_sat: 0.9982, train_accuracy: 0.0253, test_accuracy: 0.0198
# Epoch 1869, train_sat: 0.9982, test_sat: 0.9981, train_accuracy: 0.0208, test_accuracy: 0.0209
# Epoch 1870, train_sat: 0.9981, test_sat: 0.9981, train_accuracy: 0.0213, test_accuracy: 0.0210
# Epoch 1871, train_sat: 0.9981, test_sat: 0.9983, train_accuracy: 0.0215, test_accuracy: 0.0194
# Epoch 1872, train_sat: 0.9976, test_sat: 0.9981, train_accuracy: 0.0279, test_accuracy: 0.0212
# Epoch 1873, train_sat: 0.9976, test_sat: 0.9975, train_accuracy: 0.0271, test_accuracy: 0.0279
# Epoch 1874, train_sat: 0.9979, test_sat: 0.9978, train_accuracy: 0.0243, test_accuracy: 0.0249
# Epoch 1875, train_sat: 0.9980, test_sat: 0.9980, train_accuracy: 0.0225, test_accuracy: 0.0223
# Epoch 1876, train_sat: 0.9983, test_sat: 0.9982, train_accuracy: 0.0194, test_accuracy: 0.0202
# Epoch 1877, train_sat: 0.9984, test_sat: 0.9983, train_accuracy: 0.0181, test_accuracy: 0.0185
# Epoch 1878, train_sat: 0.9981, test_sat: 0.9978, train_accuracy: 0.0212, test_accuracy: 0.0249
# Epoch 1879, train_sat: 0.9983, test_sat: 0.9982, train_accuracy: 0.0189, test_accuracy: 0.0203
# Epoch 1880, train_sat: 0.9982, test_sat: 0.9981, train_accuracy: 0.0207, test_accuracy: 0.0215
# Epoch 1881, train_sat: 0.9978, test_sat: 0.9969, train_accuracy: 0.0260, test_accuracy: 0.0344
# Epoch 1882, train_sat: 0.9978, test_sat: 0.9981, train_accuracy: 0.0257, test_accuracy: 0.0212
# Epoch 1883, train_sat: 0.9976, test_sat: 0.9966, train_accuracy: 0.0278, test_accuracy: 0.0388
# Epoch 1884, train_sat: 0.9952, test_sat: 0.9965, train_accuracy: 0.0574, test_accuracy: 0.0394
# Epoch 1885, train_sat: 0.9967, test_sat: 0.9973, train_accuracy: 0.0379, test_accuracy: 0.0307
# Epoch 1886, train_sat: 0.9973, test_sat: 0.9974, train_accuracy: 0.0302, test_accuracy: 0.0291
# Epoch 1887, train_sat: 0.9979, test_sat: 0.9980, train_accuracy: 0.0244, test_accuracy: 0.0223
# Epoch 1888, train_sat: 0.9965, test_sat: 0.9969, train_accuracy: 0.0423, test_accuracy: 0.0345
# Epoch 1889, train_sat: 0.9970, test_sat: 0.9971, train_accuracy: 0.0348, test_accuracy: 0.0321
# Epoch 1890, train_sat: 0.9978, test_sat: 0.9982, train_accuracy: 0.0247, test_accuracy: 0.0199
# Epoch 1891, train_sat: 0.9977, test_sat: 0.9976, train_accuracy: 0.0259, test_accuracy: 0.0275
# Epoch 1892, train_sat: 0.9976, test_sat: 0.9976, train_accuracy: 0.0275, test_accuracy: 0.0273
# Epoch 1893, train_sat: 0.9979, test_sat: 0.9980, train_accuracy: 0.0241, test_accuracy: 0.0222
# Epoch 1894, train_sat: 0.9980, test_sat: 0.9982, train_accuracy: 0.0229, test_accuracy: 0.0198
# Epoch 1895, train_sat: 0.9982, test_sat: 0.9979, train_accuracy: 0.0204, test_accuracy: 0.0238
# Epoch 1896, train_sat: 0.9978, test_sat: 0.9979, train_accuracy: 0.0249, test_accuracy: 0.0236
# Epoch 1897, train_sat: 0.9981, test_sat: 0.9978, train_accuracy: 0.0212, test_accuracy: 0.0249
# Epoch 1898, train_sat: 0.9979, test_sat: 0.9980, train_accuracy: 0.0240, test_accuracy: 0.0221
# Epoch 1899, train_sat: 0.9981, test_sat: 0.9982, train_accuracy: 0.0221, test_accuracy: 0.0197
# Epoch 1900, train_sat: 0.9979, test_sat: 0.9980, train_accuracy: 0.0235, test_accuracy: 0.0225
# Epoch 1901, train_sat: 0.9980, test_sat: 0.9979, train_accuracy: 0.0225, test_accuracy: 0.0229
# Epoch 1902, train_sat: 0.9980, test_sat: 0.9973, train_accuracy: 0.0220, test_accuracy: 0.0301
# Epoch 1903, train_sat: 0.9980, test_sat: 0.9977, train_accuracy: 0.0222, test_accuracy: 0.0258
# Epoch 1904, train_sat: 0.9982, test_sat: 0.9977, train_accuracy: 0.0202, test_accuracy: 0.0254
# Epoch 1905, train_sat: 0.9976, test_sat: 0.9981, train_accuracy: 0.0271, test_accuracy: 0.0207
# Epoch 1906, train_sat: 0.9982, test_sat: 0.9980, train_accuracy: 0.0203, test_accuracy: 0.0220
# Epoch 1907, train_sat: 0.9981, test_sat: 0.9981, train_accuracy: 0.0216, test_accuracy: 0.0211
# Epoch 1908, train_sat: 0.9982, test_sat: 0.9980, train_accuracy: 0.0197, test_accuracy: 0.0227
# Epoch 1909, train_sat: 0.9982, test_sat: 0.9976, train_accuracy: 0.0202, test_accuracy: 0.0268
# Epoch 1910, train_sat: 0.9960, test_sat: 0.9960, train_accuracy: 0.0477, test_accuracy: 0.0459
# Epoch 1911, train_sat: 0.9977, test_sat: 0.9977, train_accuracy: 0.0256, test_accuracy: 0.0261
# Epoch 1912, train_sat: 0.9976, test_sat: 0.9981, train_accuracy: 0.0275, test_accuracy: 0.0207
# Epoch 1913, train_sat: 0.9977, test_sat: 0.9972, train_accuracy: 0.0255, test_accuracy: 0.0313
# Epoch 1914, train_sat: 0.9979, test_sat: 0.9979, train_accuracy: 0.0234, test_accuracy: 0.0230
# Epoch 1915, train_sat: 0.9983, test_sat: 0.9984, train_accuracy: 0.0192, test_accuracy: 0.0181
# Epoch 1916, train_sat: 0.9983, test_sat: 0.9982, train_accuracy: 0.0187, test_accuracy: 0.0201
# Epoch 1917, train_sat: 0.9983, test_sat: 0.9983, train_accuracy: 0.0188, test_accuracy: 0.0189
# Epoch 1918, train_sat: 0.9982, test_sat: 0.9981, train_accuracy: 0.0200, test_accuracy: 0.0217
# Epoch 1919, train_sat: 0.9981, test_sat: 0.9986, train_accuracy: 0.0218, test_accuracy: 0.0156
# Epoch 1920, train_sat: 0.9980, test_sat: 0.9973, train_accuracy: 0.0223, test_accuracy: 0.0305
# Epoch 1921, train_sat: 0.9975, test_sat: 0.9977, train_accuracy: 0.0282, test_accuracy: 0.0261
# Epoch 1922, train_sat: 0.9979, test_sat: 0.9979, train_accuracy: 0.0240, test_accuracy: 0.0238
# Epoch 1923, train_sat: 0.9977, test_sat: 0.9976, train_accuracy: 0.0262, test_accuracy: 0.0274
# Epoch 1924, train_sat: 0.9971, test_sat: 0.9966, train_accuracy: 0.0337, test_accuracy: 0.0384
# Epoch 1925, train_sat: 0.9973, test_sat: 0.9983, train_accuracy: 0.0320, test_accuracy: 0.0186
# Epoch 1926, train_sat: 0.9979, test_sat: 0.9975, train_accuracy: 0.0240, test_accuracy: 0.0280
# Epoch 1927, train_sat: 0.9980, test_sat: 0.9977, train_accuracy: 0.0232, test_accuracy: 0.0254
# Epoch 1928, train_sat: 0.9982, test_sat: 0.9979, train_accuracy: 0.0204, test_accuracy: 0.0232
# Epoch 1929, train_sat: 0.9981, test_sat: 0.9981, train_accuracy: 0.0212, test_accuracy: 0.0209
# Epoch 1930, train_sat: 0.9981, test_sat: 0.9979, train_accuracy: 0.0216, test_accuracy: 0.0241
# Epoch 1931, train_sat: 0.9974, test_sat: 0.9975, train_accuracy: 0.0301, test_accuracy: 0.0279
# Epoch 1932, train_sat: 0.9980, test_sat: 0.9980, train_accuracy: 0.0228, test_accuracy: 0.0223
# Epoch 1933, train_sat: 0.9981, test_sat: 0.9977, train_accuracy: 0.0218, test_accuracy: 0.0256
# Epoch 1934, train_sat: 0.9981, test_sat: 0.9981, train_accuracy: 0.0215, test_accuracy: 0.0211
# Epoch 1935, train_sat: 0.9983, test_sat: 0.9986, train_accuracy: 0.0189, test_accuracy: 0.0156
# Epoch 1936, train_sat: 0.9983, test_sat: 0.9978, train_accuracy: 0.0196, test_accuracy: 0.0242
# Epoch 1937, train_sat: 0.9973, test_sat: 0.9974, train_accuracy: 0.0321, test_accuracy: 0.0290
# Epoch 1938, train_sat: 0.9974, test_sat: 0.9969, train_accuracy: 0.0301, test_accuracy: 0.0347
# Epoch 1939, train_sat: 0.9977, test_sat: 0.9971, train_accuracy: 0.0273, test_accuracy: 0.0321
# Epoch 1940, train_sat: 0.9980, test_sat: 0.9982, train_accuracy: 0.0228, test_accuracy: 0.0204
# Epoch 1941, train_sat: 0.9984, test_sat: 0.9982, train_accuracy: 0.0184, test_accuracy: 0.0196
# Epoch 1942, train_sat: 0.9983, test_sat: 0.9983, train_accuracy: 0.0195, test_accuracy: 0.0192
# Epoch 1943, train_sat: 0.9979, test_sat: 0.9976, train_accuracy: 0.0236, test_accuracy: 0.0272
# Epoch 1944, train_sat: 0.9978, test_sat: 0.9979, train_accuracy: 0.0256, test_accuracy: 0.0235
# Epoch 1945, train_sat: 0.9981, test_sat: 0.9977, train_accuracy: 0.0215, test_accuracy: 0.0259
# Epoch 1946, train_sat: 0.9981, test_sat: 0.9981, train_accuracy: 0.0218, test_accuracy: 0.0209
# Epoch 1947, train_sat: 0.9982, test_sat: 0.9980, train_accuracy: 0.0205, test_accuracy: 0.0220
# Epoch 1948, train_sat: 0.9980, test_sat: 0.9982, train_accuracy: 0.0226, test_accuracy: 0.0195
# Epoch 1949, train_sat: 0.9979, test_sat: 0.9980, train_accuracy: 0.0242, test_accuracy: 0.0218
# Epoch 1950, train_sat: 0.9976, test_sat: 0.9981, train_accuracy: 0.0274, test_accuracy: 0.0212
# Epoch 1951, train_sat: 0.9977, test_sat: 0.9980, train_accuracy: 0.0264, test_accuracy: 0.0231
# Epoch 1952, train_sat: 0.9963, test_sat: 0.9975, train_accuracy: 0.0451, test_accuracy: 0.0277
# Epoch 1953, train_sat: 0.9979, test_sat: 0.9983, train_accuracy: 0.0242, test_accuracy: 0.0193
# Epoch 1954, train_sat: 0.9976, test_sat: 0.9967, train_accuracy: 0.0272, test_accuracy: 0.0378
# Epoch 1955, train_sat: 0.9974, test_sat: 0.9982, train_accuracy: 0.0306, test_accuracy: 0.0197
# Epoch 1956, train_sat: 0.9979, test_sat: 0.9982, train_accuracy: 0.0243, test_accuracy: 0.0204
# Epoch 1957, train_sat: 0.9982, test_sat: 0.9978, train_accuracy: 0.0206, test_accuracy: 0.0242
# Epoch 1958, train_sat: 0.9982, test_sat: 0.9981, train_accuracy: 0.0206, test_accuracy: 0.0206
# Epoch 1959, train_sat: 0.9979, test_sat: 0.9969, train_accuracy: 0.0244, test_accuracy: 0.0347
# Epoch 1960, train_sat: 0.9970, test_sat: 0.9972, train_accuracy: 0.0353, test_accuracy: 0.0319
# Epoch 1961, train_sat: 0.9974, test_sat: 0.9977, train_accuracy: 0.0297, test_accuracy: 0.0263
# Epoch 1962, train_sat: 0.9979, test_sat: 0.9983, train_accuracy: 0.0238, test_accuracy: 0.0186
# Epoch 1963, train_sat: 0.9980, test_sat: 0.9975, train_accuracy: 0.0226, test_accuracy: 0.0275
# Epoch 1964, train_sat: 0.9980, test_sat: 0.9975, train_accuracy: 0.0227, test_accuracy: 0.0276
# Epoch 1965, train_sat: 0.9979, test_sat: 0.9975, train_accuracy: 0.0233, test_accuracy: 0.0279
# Epoch 1966, train_sat: 0.9980, test_sat: 0.9981, train_accuracy: 0.0227, test_accuracy: 0.0208
# Epoch 1967, train_sat: 0.9981, test_sat: 0.9979, train_accuracy: 0.0217, test_accuracy: 0.0231
# Epoch 1968, train_sat: 0.9983, test_sat: 0.9986, train_accuracy: 0.0194, test_accuracy: 0.0150
# Epoch 1969, train_sat: 0.9984, test_sat: 0.9982, train_accuracy: 0.0177, test_accuracy: 0.0201
# Epoch 1970, train_sat: 0.9981, test_sat: 0.9974, train_accuracy: 0.0219, test_accuracy: 0.0293
# Epoch 1971, train_sat: 0.9975, test_sat: 0.9978, train_accuracy: 0.0299, test_accuracy: 0.0248
# Epoch 1972, train_sat: 0.9983, test_sat: 0.9980, train_accuracy: 0.0194, test_accuracy: 0.0222
# Epoch 1973, train_sat: 0.9982, test_sat: 0.9980, train_accuracy: 0.0207, test_accuracy: 0.0222
# Epoch 1974, train_sat: 0.9980, test_sat: 0.9983, train_accuracy: 0.0226, test_accuracy: 0.0193
# Epoch 1975, train_sat: 0.9980, test_sat: 0.9978, train_accuracy: 0.0230, test_accuracy: 0.0245
# Epoch 1976, train_sat: 0.9982, test_sat: 0.9975, train_accuracy: 0.0205, test_accuracy: 0.0280
# Epoch 1977, train_sat: 0.9979, test_sat: 0.9973, train_accuracy: 0.0235, test_accuracy: 0.0306
# Epoch 1978, train_sat: 0.9967, test_sat: 0.9951, train_accuracy: 0.0393, test_accuracy: 0.0560
# Epoch 1979, train_sat: 0.9963, test_sat: 0.9981, train_accuracy: 0.0472, test_accuracy: 0.0216
# Epoch 1980, train_sat: 0.9979, test_sat: 0.9982, train_accuracy: 0.0244, test_accuracy: 0.0196
# Epoch 1981, train_sat: 0.9983, test_sat: 0.9981, train_accuracy: 0.0193, test_accuracy: 0.0209
# Epoch 1982, train_sat: 0.9982, test_sat: 0.9977, train_accuracy: 0.0206, test_accuracy: 0.0256
# Epoch 1983, train_sat: 0.9979, test_sat: 0.9981, train_accuracy: 0.0244, test_accuracy: 0.0216
# Epoch 1984, train_sat: 0.9978, test_sat: 0.9972, train_accuracy: 0.0262, test_accuracy: 0.0314
# Epoch 1985, train_sat: 0.9966, test_sat: 0.9975, train_accuracy: 0.0402, test_accuracy: 0.0287
# Epoch 1986, train_sat: 0.9976, test_sat: 0.9975, train_accuracy: 0.0278, test_accuracy: 0.0281
# Epoch 1987, train_sat: 0.9981, test_sat: 0.9974, train_accuracy: 0.0218, test_accuracy: 0.0292
# Epoch 1988, train_sat: 0.9965, test_sat: 0.9978, train_accuracy: 0.0430, test_accuracy: 0.0249
# Epoch 1989, train_sat: 0.9979, test_sat: 0.9983, train_accuracy: 0.0239, test_accuracy: 0.0189
# Epoch 1990, train_sat: 0.9982, test_sat: 0.9981, train_accuracy: 0.0209, test_accuracy: 0.0209
# Epoch 1991, train_sat: 0.9981, test_sat: 0.9976, train_accuracy: 0.0208, test_accuracy: 0.0269
# Epoch 1992, train_sat: 0.9982, test_sat: 0.9984, train_accuracy: 0.0201, test_accuracy: 0.0177
# Epoch 1993, train_sat: 0.9984, test_sat: 0.9983, train_accuracy: 0.0182, test_accuracy: 0.0184
# Epoch 1994, train_sat: 0.9982, test_sat: 0.9979, train_accuracy: 0.0202, test_accuracy: 0.0233
# Epoch 1995, train_sat: 0.9981, test_sat: 0.9985, train_accuracy: 0.0211, test_accuracy: 0.0171
# Epoch 1996, train_sat: 0.9982, test_sat: 0.9980, train_accuracy: 0.0197, test_accuracy: 0.0228
# Epoch 1997, train_sat: 0.9978, test_sat: 0.9978, train_accuracy: 0.0250, test_accuracy: 0.0251
# Epoch 1998, train_sat: 0.9970, test_sat: 0.9973, train_accuracy: 0.0354, test_accuracy: 0.0305
# Epoch 1999, train_sat: 0.9971, test_sat: 0.9980, train_accuracy: 0.0336, test_accuracy: 0.0226

# %%
import seaborn as sns
sns.set(font_scale=1.2)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("LTN_regresie_1.pdf")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("LTN_regresie_2")
plt.show()

# %%
# figure, axis = plt.subplots(figsize=(12,8))
# x_ax = range(51)
# axis.plot(x_ax, data['y_true'].tail(50), label="Pozitie", color='c')
# axis.plot(x_ax, data['y_pred'].tail(50), label="Pozitie-pred", color='b')
# axis.legend()


# plt.savefig('test.pdf')  
# plt.show()

# %%
# fig, axs = plt.subplots(1,2,figsize=(12,6))
# ax = axs[0]
# data = {'y_pred':[],'y_true':[]}
# for x,y in ds_comp_train:
#     data['y_pred'].extend(f.model(x)[:,0].numpy())
#     data['y_true'].extend(y[:,0].numpy())
# df = pd.DataFrame(data,columns=['y_pred','y_true'])
# ax.set_xlim(0,80)
# ax.set_ylim(0,80)
# sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
#             scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
# ax.plot([0,100],[0,100],color="gray",linestyle="--")
# ax.set_xlabel("Actual y values")
# ax.set_ylabel("Fitted y values")
# ax.set_title("Training Data")

# # ax = axs[1]
# data = {'y_pred':[],'y_true':[]}
# for x,y in ds_comp_test:
#     data['y_pred'].extend(f.model(x)[:,0].numpy())
#     data['y_true'].extend(y[:,0].numpy())
# df = pd.DataFrame(data,columns=['y_pred','y_true'])
# ax.set_ylim(0,80)
# ax.set_xlim(0,80)
# sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
#             scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
# ax.plot([0,100],[0,100],color="gray",linestyle="--")
# ax.set_xlabel("Actual y values")
# ax.set_ylabel("Fitted y values")
# ax.set_title("Test Data")
# plt.tight_layout()
# plt.savefig("LTN_regresie_1.pdf")

# %%
# figure, axis = plt.subplots(figsize=(12,8))
# x_ax = range(50)
# axis.plot(x_ax, data['y_true'], label="Pozitie", color='c')
# axis.plot(x_ax, data['y_pred'], label="Pozitie-pred", color='b')
# axis.legend()


# plt.savefig('test_general.pdf')  
# plt.show()

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training_sectiune/tot.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Severitate def', 'Severitate inc.','Pozitie']]
batch_size= 32
ds_test = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

data = {'y_pred':[],'y_true':[],'def':[],'inc':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
    data['def'].extend(y[:,0].numpy())
    data['inc'].extend(y[:,1].numpy())
data_plot = pd.DataFrame(data,columns=['y_pred','y_true','def','inc'])
#'Severitate def', 'Severitate inc.'

# %%
data_plot.head(4)
# Out:
#      y_pred  y_true       def       inc
# 0  0.805546   0.824  0.002141  0.000567
# 1  0.597994   0.616  0.020444  0.001020
# 2  0.559043   0.596  0.007105  0.001593
# 3  0.951424   0.924  0.001191  0.000567

# %%
data_plot.shape
# Out:
# (36573, 4)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

sns.scatterplot(data=data_plot, x="y_pred", y="y_true", hue="def")
plt.legend(title = 'Severitate defect transversal', fontsize='20', title_fontsize='20')
plt.xlabel("Position predicted value", size=20)
plt.ylabel("Position actual value", size=20)
plt.savefig("def.png")

# %%
sns.scatterplot(data=data_plot, x="y_pred", y="y_true", hue="inc")
plt.legend(title = 'Severitate incastrare', fontsize='20', title_fontsize='20')
plt.xlabel("Position predicted value", size=20)
plt.ylabel("Position actual value", size=20)
plt.savefig("inc.png")

# %%
data_plot['def'].unique
# Out:
# <bound method Series.unique of 0        0.002141
# 1        0.020444
# 2        0.007105
# 3        0.001191
# 4        0.001191
#            ...
# 36568    0.002141
# 36569    0.051453
# 36570    0.016030
# 36571    0.032690
# 36572    0.051453
# Name: def, Length: 36573, dtype: float64>

# %%
dif = abs( data_plot["y_pred"] - data_plot["y_true"])

# %%
index = -1
for i in dif:
    index+=1
    if i>4:
        print(i)
        print(index)

# %%
plt.stem(dif.head(100))
# Out:
# <StemContainer object of 3 artists>

# %%
data_plot.head(100).corr()
# Out:
#           y_pred    y_true       def       inc
# y_pred  1.000000  0.991949  0.004351 -0.031899
# y_true  0.991949  1.000000  0.020202 -0.013815
# def     0.004351  0.020202  1.000000  0.038733
# inc    -0.031899 -0.013815  0.038733  1.000000

# %%
index = -1
for i in dif.head(100):
    index+=1
    if i>0.1:
        print(i)
        print(index)
# Out:
# 0.15751796197891238
# 27
# 0.12813477134704587
# 37

# %%
data_plot.iloc[47]
# Out:
# y_pred    0.505824
# y_true    0.536000
# def       0.032690
# inc       0.000567
# Name: 47, dtype: float64

# %%
#severitatea def afecteaza cel mai mult, cand aceasta creste modelul prezice mai bine

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/date_test_corectate.csv", on_bad_lines='skip')

# %%
df = df.sample(frac=1) #shuffle
x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Severitate def', 'Severitate inc.','Pozitie']]
batch_size= 32
ds_test = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

data = {'y_pred':[],'y_true':[],'def':[],'inc':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
    data['def'].extend(y[:,0].numpy())
    data['inc'].extend(y[:,1].numpy())
data_plot = pd.DataFrame(data,columns=['y_pred','y_true','def','inc'])
#'Severitate def', 'Severitate inc.'

# %%
dif = abs( data_plot["y_pred"] - data_plot["y_true"])

# %%
plt.stem(dif)
# Out:
# <StemContainer object of 3 artists>

# %%
index = -1
for i in dif:
    index+=1
    if i>0.07:
        print(i)
        print(index)
# Out:
# 0.07627153158187872
# 6

# %%
data_plot.iloc[6]
# Out:
# y_pred    0.483728
# y_true    0.560000
# def       0.003346
# inc       0.000000
# Name: 6, dtype: float64

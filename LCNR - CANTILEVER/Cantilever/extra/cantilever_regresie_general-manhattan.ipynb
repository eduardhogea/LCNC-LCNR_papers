# %%
import logging; logging.basicConfig(level=logging.INFO)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import logictensornetworks as ltn
import pandas as pd

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training_sectiune/tot.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
df_comp = df.sample(50) # un numar de valori random sa vedem acuratetea
#df.sample(5)
#df.shape
df = df.sample(int(len(df)*(100/100)))
print(df.shape)
# Out:
# (36573, 11)

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# #df = scaler.fit_transform(df)

# %%
df.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df.shape
# Out:
# Null values in dataset are 0
# (36573, 11)

# %%
df_comp.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df_comp.replace([np.inf, -np.inf], np.nan, inplace=True)
df_comp.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df_comp.shape
# Out:
# Null values in dataset are 0
# (50, 11)

# %%
from sklearn.model_selection import train_test_split


x = df[['Severitate def', 'Severitate inc.','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Pozitie']]

x_comp = df_comp[['Severitate def', 'Severitate inc.','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y_comp = df_comp[['Pozitie']]


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2)

#x_comp_train, x_comp_test, y_comp_train, y_comp_test = train_test_split(x_comp, y_comp, test_size=.2)

# %%
batch_size= 64
ds_train = tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(batch_size)
ds_test = tf.data.Dataset.from_tensor_slices((x_test,y_test)).batch(batch_size)

#ds_comp_train = tf.data.Dataset.from_tensor_slices((x_comp_train,y_comp_train)).batch(batch_size)
ds_comp_test = tf.data.Dataset.from_tensor_slices((x_comp,y_comp)).batch(batch_size)
# Out:
# Metal device set to: Apple M1
# 2022-06-10 17:45:59.260691: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-10 17:45:59.261080: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#df['Freq 1    f1 [Hz]'] = df['Freq 1    f1 [Hz]'].astype(float, errors = 'raise')
df.dtypes
# Out:
# Pozitie            float64
# Severitate def     float64
# Severitate inc.    float64
# Mod 1              float64
# Mod 2              float64
# Mod 3              float64
# Mod 4              float64
# Mod 5              float64
# Mod 6              float64
# Mod 7              float64
# Mod 8              float64
# dtype: object

# %%
f = ltn.Function.MLP(input_shapes=[10],output_shape=[1],hidden_layer_sizes=(100,100,50))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*(tf.reduce_sum(abs(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.79122
# 2022-06-10 17:46:00.033915: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-10 17:46:00.034496: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.005)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train, 
        ds_test, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 100

modelul = train(
    EPOCHS,
    metrics_dict,
    ds_train,
    ds_test,
    train_step,
    test_step,
    csv_path="testtest.csv",
    track_metrics=1
)
# Out:
# 2022-06-10 17:46:00.284175: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-10 17:46:05.107859: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-10 17:46:05.275721: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-10 17:46:05.733487: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.9106, test_sat: 0.9201, train_accuracy: 0.2117, test_accuracy: 0.1845
# Epoch 1, train_sat: 0.9367, test_sat: 0.9517, train_accuracy: 0.1465, test_accuracy: 0.1089
# Epoch 2, train_sat: 0.9494, test_sat: 0.9470, train_accuracy: 0.1166, test_accuracy: 0.1227
# Epoch 3, train_sat: 0.9540, test_sat: 0.9526, train_accuracy: 0.1061, test_accuracy: 0.1030
# Epoch 4, train_sat: 0.9556, test_sat: 0.9553, train_accuracy: 0.1033, test_accuracy: 0.1030
# Epoch 5, train_sat: 0.9589, test_sat: 0.9582, train_accuracy: 0.0962, test_accuracy: 0.0906
# Epoch 6, train_sat: 0.9624, test_sat: 0.9437, train_accuracy: 0.0864, test_accuracy: 0.1253
# Epoch 7, train_sat: 0.9609, test_sat: 0.9675, train_accuracy: 0.0921, test_accuracy: 0.0710
# Epoch 8, train_sat: 0.9666, test_sat: 0.9439, train_accuracy: 0.0772, test_accuracy: 0.1326
# Epoch 9, train_sat: 0.9662, test_sat: 0.9733, train_accuracy: 0.0789, test_accuracy: 0.0576
# Epoch 10, train_sat: 0.9678, test_sat: 0.9539, train_accuracy: 0.0745, test_accuracy: 0.1077
# Epoch 11, train_sat: 0.9687, test_sat: 0.9593, train_accuracy: 0.0735, test_accuracy: 0.0905
# Epoch 12, train_sat: 0.9684, test_sat: 0.9603, train_accuracy: 0.0726, test_accuracy: 0.0894
# Epoch 13, train_sat: 0.9710, test_sat: 0.9841, train_accuracy: 0.0679, test_accuracy: 0.0338
# Epoch 14, train_sat: 0.9691, test_sat: 0.9591, train_accuracy: 0.0727, test_accuracy: 0.0921
# Epoch 15, train_sat: 0.9720, test_sat: 0.9601, train_accuracy: 0.0654, test_accuracy: 0.0902
# Epoch 16, train_sat: 0.9736, test_sat: 0.9510, train_accuracy: 0.0619, test_accuracy: 0.1138
# Epoch 17, train_sat: 0.9705, test_sat: 0.9470, train_accuracy: 0.0711, test_accuracy: 0.1247
# Epoch 18, train_sat: 0.9737, test_sat: 0.9533, train_accuracy: 0.0614, test_accuracy: 0.1091
# Epoch 19, train_sat: 0.9727, test_sat: 0.9701, train_accuracy: 0.0637, test_accuracy: 0.0653
# Epoch 20, train_sat: 0.9751, test_sat: 0.9786, train_accuracy: 0.0579, test_accuracy: 0.0455
# Epoch 21, train_sat: 0.9756, test_sat: 0.9778, train_accuracy: 0.0570, test_accuracy: 0.0485
# Epoch 22, train_sat: 0.9757, test_sat: 0.9590, train_accuracy: 0.0568, test_accuracy: 0.0941
# Epoch 23, train_sat: 0.9749, test_sat: 0.9591, train_accuracy: 0.0598, test_accuracy: 0.0874
# Epoch 24, train_sat: 0.9761, test_sat: 0.9823, train_accuracy: 0.0564, test_accuracy: 0.0365
# Epoch 25, train_sat: 0.9771, test_sat: 0.9875, train_accuracy: 0.0538, test_accuracy: 0.0265
# Epoch 26, train_sat: 0.9775, test_sat: 0.9801, train_accuracy: 0.0535, test_accuracy: 0.0424
# Epoch 27, train_sat: 0.9781, test_sat: 0.9637, train_accuracy: 0.0512, test_accuracy: 0.0815
# Epoch 28, train_sat: 0.9773, test_sat: 0.9761, train_accuracy: 0.0536, test_accuracy: 0.0511
# Epoch 29, train_sat: 0.9790, test_sat: 0.9822, train_accuracy: 0.0487, test_accuracy: 0.0371
# Epoch 30, train_sat: 0.9792, test_sat: 0.9657, train_accuracy: 0.0490, test_accuracy: 0.0742
# Epoch 31, train_sat: 0.9774, test_sat: 0.9856, train_accuracy: 0.0534, test_accuracy: 0.0305
# Epoch 32, train_sat: 0.9784, test_sat: 0.9652, train_accuracy: 0.0517, test_accuracy: 0.0748
# Epoch 33, train_sat: 0.9778, test_sat: 0.9712, train_accuracy: 0.0530, test_accuracy: 0.0618
# Epoch 34, train_sat: 0.9790, test_sat: 0.9872, train_accuracy: 0.0491, test_accuracy: 0.0272
# Epoch 35, train_sat: 0.9800, test_sat: 0.9808, train_accuracy: 0.0468, test_accuracy: 0.0405
# Epoch 36, train_sat: 0.9804, test_sat: 0.9606, train_accuracy: 0.0453, test_accuracy: 0.0899
# Epoch 37, train_sat: 0.9778, test_sat: 0.9664, train_accuracy: 0.0530, test_accuracy: 0.0731
# Epoch 38, train_sat: 0.9811, test_sat: 0.9866, train_accuracy: 0.0444, test_accuracy: 0.0280
# Epoch 39, train_sat: 0.9791, test_sat: 0.9588, train_accuracy: 0.0493, test_accuracy: 0.0947
# Epoch 40, train_sat: 0.9803, test_sat: 0.9589, train_accuracy: 0.0463, test_accuracy: 0.0920
# Epoch 41, train_sat: 0.9799, test_sat: 0.9660, train_accuracy: 0.0474, test_accuracy: 0.0764
# Epoch 42, train_sat: 0.9799, test_sat: 0.9890, train_accuracy: 0.0471, test_accuracy: 0.0231
# Epoch 43, train_sat: 0.9807, test_sat: 0.9851, train_accuracy: 0.0449, test_accuracy: 0.0315
# Epoch 44, train_sat: 0.9811, test_sat: 0.9823, train_accuracy: 0.0441, test_accuracy: 0.0375
# Epoch 45, train_sat: 0.9820, test_sat: 0.9919, train_accuracy: 0.0424, test_accuracy: 0.0172
# Epoch 46, train_sat: 0.9808, test_sat: 0.9849, train_accuracy: 0.0448, test_accuracy: 0.0315
# Epoch 47, train_sat: 0.9817, test_sat: 0.9712, train_accuracy: 0.0428, test_accuracy: 0.0637
# Epoch 48, train_sat: 0.9817, test_sat: 0.9744, train_accuracy: 0.0424, test_accuracy: 0.0553
# Epoch 49, train_sat: 0.9815, test_sat: 0.9743, train_accuracy: 0.0431, test_accuracy: 0.0564
# Epoch 50, train_sat: 0.9807, test_sat: 0.9648, train_accuracy: 0.0444, test_accuracy: 0.0785
# Epoch 51, train_sat: 0.9818, test_sat: 0.9738, train_accuracy: 0.0428, test_accuracy: 0.0576
# Epoch 52, train_sat: 0.9815, test_sat: 0.9926, train_accuracy: 0.0438, test_accuracy: 0.0153
# Epoch 53, train_sat: 0.9833, test_sat: 0.9752, train_accuracy: 0.0385, test_accuracy: 0.0546
# Epoch 54, train_sat: 0.9831, test_sat: 0.9730, train_accuracy: 0.0395, test_accuracy: 0.0592
# Epoch 55, train_sat: 0.9828, test_sat: 0.9733, train_accuracy: 0.0409, test_accuracy: 0.0589
# Epoch 56, train_sat: 0.9818, test_sat: 0.9810, train_accuracy: 0.0417, test_accuracy: 0.0401
# Epoch 57, train_sat: 0.9833, test_sat: 0.9725, train_accuracy: 0.0389, test_accuracy: 0.0596
# Epoch 58, train_sat: 0.9834, test_sat: 0.9900, train_accuracy: 0.0390, test_accuracy: 0.0211
# Epoch 59, train_sat: 0.9835, test_sat: 0.9716, train_accuracy: 0.0386, test_accuracy: 0.0629
# Epoch 60, train_sat: 0.9825, test_sat: 0.9764, train_accuracy: 0.0412, test_accuracy: 0.0513
# Epoch 61, train_sat: 0.9831, test_sat: 0.9763, train_accuracy: 0.0387, test_accuracy: 0.0514
# Epoch 62, train_sat: 0.9823, test_sat: 0.9745, train_accuracy: 0.0422, test_accuracy: 0.0556
# Epoch 63, train_sat: 0.9841, test_sat: 0.9820, train_accuracy: 0.0370, test_accuracy: 0.0378
# Epoch 64, train_sat: 0.9853, test_sat: 0.9891, train_accuracy: 0.0348, test_accuracy: 0.0225
# Epoch 65, train_sat: 0.9843, test_sat: 0.9661, train_accuracy: 0.0365, test_accuracy: 0.0749
# Epoch 66, train_sat: 0.9830, test_sat: 0.9554, train_accuracy: 0.0398, test_accuracy: 0.1013
# Epoch 67, train_sat: 0.9853, test_sat: 0.9719, train_accuracy: 0.0340, test_accuracy: 0.0616
# Epoch 68, train_sat: 0.9840, test_sat: 0.9822, train_accuracy: 0.0379, test_accuracy: 0.0376
# Epoch 69, train_sat: 0.9835, test_sat: 0.9918, train_accuracy: 0.0382, test_accuracy: 0.0168
# Epoch 70, train_sat: 0.9846, test_sat: 0.9933, train_accuracy: 0.0363, test_accuracy: 0.0135
# Epoch 71, train_sat: 0.9849, test_sat: 0.9551, train_accuracy: 0.0360, test_accuracy: 0.1015
# Epoch 72, train_sat: 0.9846, test_sat: 0.9935, train_accuracy: 0.0359, test_accuracy: 0.0135
# Epoch 73, train_sat: 0.9853, test_sat: 0.9875, train_accuracy: 0.0340, test_accuracy: 0.0261
# Epoch 74, train_sat: 0.9849, test_sat: 0.9928, train_accuracy: 0.0355, test_accuracy: 0.0147
# Epoch 75, train_sat: 0.9835, test_sat: 0.9747, train_accuracy: 0.0396, test_accuracy: 0.0544
# Epoch 76, train_sat: 0.9845, test_sat: 0.9644, train_accuracy: 0.0354, test_accuracy: 0.0800
# Epoch 77, train_sat: 0.9843, test_sat: 0.9787, train_accuracy: 0.0367, test_accuracy: 0.0463
# Epoch 78, train_sat: 0.9848, test_sat: 0.9836, train_accuracy: 0.0353, test_accuracy: 0.0348
# Epoch 79, train_sat: 0.9863, test_sat: 0.9885, train_accuracy: 0.0331, test_accuracy: 0.0235
# Epoch 80, train_sat: 0.9842, test_sat: 0.9952, train_accuracy: 0.0375, test_accuracy: 0.0097
# Epoch 81, train_sat: 0.9858, test_sat: 0.9900, train_accuracy: 0.0330, test_accuracy: 0.0203
# Epoch 82, train_sat: 0.9854, test_sat: 0.9884, train_accuracy: 0.0338, test_accuracy: 0.0244
# Epoch 83, train_sat: 0.9859, test_sat: 0.9675, train_accuracy: 0.0328, test_accuracy: 0.0738
# Epoch 84, train_sat: 0.9860, test_sat: 0.9904, train_accuracy: 0.0337, test_accuracy: 0.0209
# Epoch 85, train_sat: 0.9861, test_sat: 0.9908, train_accuracy: 0.0327, test_accuracy: 0.0188
# Epoch 86, train_sat: 0.9848, test_sat: 0.9934, train_accuracy: 0.0360, test_accuracy: 0.0135
# Epoch 87, train_sat: 0.9865, test_sat: 0.9898, train_accuracy: 0.0313, test_accuracy: 0.0216
# Epoch 88, train_sat: 0.9868, test_sat: 0.9821, train_accuracy: 0.0302, test_accuracy: 0.0368
# Epoch 89, train_sat: 0.9881, test_sat: 0.9944, train_accuracy: 0.0270, test_accuracy: 0.0118
# Epoch 90, train_sat: 0.9871, test_sat: 0.9897, train_accuracy: 0.0308, test_accuracy: 0.0213
# Epoch 91, train_sat: 0.9866, test_sat: 0.9815, train_accuracy: 0.0311, test_accuracy: 0.0394
# Epoch 92, train_sat: 0.9871, test_sat: 0.9839, train_accuracy: 0.0297, test_accuracy: 0.0342
# Epoch 93, train_sat: 0.9868, test_sat: 0.9784, train_accuracy: 0.0304, test_accuracy: 0.0461
# Epoch 94, train_sat: 0.9879, test_sat: 0.9811, train_accuracy: 0.0283, test_accuracy: 0.0406
# Epoch 95, train_sat: 0.9880, test_sat: 0.9856, train_accuracy: 0.0284, test_accuracy: 0.0304
# Epoch 96, train_sat: 0.9860, test_sat: 0.9938, train_accuracy: 0.0338, test_accuracy: 0.0124
# Epoch 97, train_sat: 0.9885, test_sat: 0.9842, train_accuracy: 0.0267, test_accuracy: 0.0340
# Epoch 98, train_sat: 0.9878, test_sat: 0.9843, train_accuracy: 0.0281, test_accuracy: 0.0335
# Epoch 99, train_sat: 0.9882, test_sat: 0.9804, train_accuracy: 0.0274, test_accuracy: 0.0416

# %%
import seaborn as sns
sns.set(font_scale=1.2)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("LTN_regresie_manhattan.pdf")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("LTN_regresie_manhattan")
plt.show()

# %%
# figure, axis = plt.subplots(figsize=(12,8))
# x_ax = range(51)
# axis.plot(x_ax, data['y_true'].tail(50), label="Pozitie", color='c')
# axis.plot(x_ax, data['y_pred'].tail(50), label="Pozitie-pred", color='b')
# axis.legend()


# plt.savefig('test.pdf')  
# plt.show()

# %%
# fig, axs = plt.subplots(1,2,figsize=(12,6))
# ax = axs[0]
# data = {'y_pred':[],'y_true':[]}
# for x,y in ds_comp_train:
#     data['y_pred'].extend(f.model(x)[:,0].numpy())
#     data['y_true'].extend(y[:,0].numpy())
# df = pd.DataFrame(data,columns=['y_pred','y_true'])
# ax.set_xlim(0,80)
# ax.set_ylim(0,80)
# sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
#             scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
# ax.plot([0,100],[0,100],color="gray",linestyle="--")
# ax.set_xlabel("Actual y values")
# ax.set_ylabel("Fitted y values")
# ax.set_title("Training Data")

# # ax = axs[1]
# data = {'y_pred':[],'y_true':[]}
# for x,y in ds_comp_test:
#     data['y_pred'].extend(f.model(x)[:,0].numpy())
#     data['y_true'].extend(y[:,0].numpy())
# df = pd.DataFrame(data,columns=['y_pred','y_true'])
# ax.set_ylim(0,80)
# ax.set_xlim(0,80)
# sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
#             scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
# ax.plot([0,100],[0,100],color="gray",linestyle="--")
# ax.set_xlabel("Actual y values")
# ax.set_ylabel("Fitted y values")
# ax.set_title("Test Data")
# plt.tight_layout()
# plt.savefig("LTN_regresie_1.pdf")

# %%
# figure, axis = plt.subplots(figsize=(12,8))
# x_ax = range(50)
# axis.plot(x_ax, data['y_true'], label="Pozitie", color='c')
# axis.plot(x_ax, data['y_pred'], label="Pozitie-pred", color='b')
# axis.legend()


# plt.savefig('test_general.pdf')  
# plt.show()

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training_sectiune/tot.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
x = df[['Severitate def', 'Severitate inc.','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Pozitie']]
batch_size= 32
ds_test = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

data = {'y_pred':[],'y_true':[],'def':[],'inc':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
    data['def'].extend(x[:,0].numpy())
    data['inc'].extend(x[:,1].numpy())
data_plot = pd.DataFrame(data,columns=['y_pred','y_true','def','inc'])
#'Severitate def', 'Severitate inc.'

# %%
data_plot.head(4)
# Out:
#      y_pred  y_true       def       inc
# 0  0.199274   0.204  0.051453  0.001020
# 1  0.860280   0.848  0.032690  0.000000
# 2  0.245471   0.234  0.066210  0.000000
# 3  0.264918   0.256  0.012434  0.000567

# %%
data_plot.shape
# Out:
# (36573, 4)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

sns.scatterplot(data=data_plot, x="y_pred", y="y_true", hue="def")
plt.legend(title = 'Severitate def', fontsize='20', title_fontsize='20')
plt.xlabel("Predicted value", size=20)
plt.ylabel("Actual value", size=20)
plt.savefig("def_manhattan_v2.png")

# %%
sns.scatterplot(data=data_plot, x="y_pred", y="y_true", hue="inc")
plt.legend(title = 'Severitate incastrare', fontsize='20', title_fontsize='20')
plt.xlabel("Predicted value", size=20)
plt.ylabel("Actual value", size=20)
plt.savefig("inc_manhattan_v2.png")

# %%
data_plot['def'].unique
# Out:
# <bound method Series.unique of 0        0.051453
# 1        0.032690
# 2        0.066210
# 3        0.012434
# 4        0.001191
#            ...
# 36568    0.020444
# 36569    0.002141
# 36570    0.005124
# 36571    0.012434
# 36572    0.000867
# Name: def, Length: 36573, dtype: float64>

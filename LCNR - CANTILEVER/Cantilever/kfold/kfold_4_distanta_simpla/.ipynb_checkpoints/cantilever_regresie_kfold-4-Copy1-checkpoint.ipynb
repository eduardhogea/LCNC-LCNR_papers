# %%
import logging; logging.basicConfig(level=logging.INFO)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import logictensornetworks as ltn
import pandas as pd
import seaborn as sns
sns.set(font_scale=1.2)
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training_sectiune/tot.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
#df_comp = df.sample(50) # un numar de valori random sa vedem acuratetea
#df.sample(5)
#df.shape
df = df.sample(int(len(df)*(100/100)))
print(df.shape)
# Out:
# (36573, 11)

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# #df = scaler.fit_transform(df)

# %%
df.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df.shape
# Out:
# Null values in dataset are 0
# (36573, 11)

# %%
# df_comp.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
# df_comp.replace([np.inf, -np.inf], np.nan, inplace=True)
# df_comp.dropna(inplace = True)
# print('Null values in dataset are',len(df[df.isnull().any(1)]))
# df_comp.shape

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits = 4, shuffle = True, random_state = 42)
listakf = list(kf.split(df))

# %%
result = listakf[0]
train = df.iloc[result[0]]
test =  df.iloc[result[1]]
result2 = listakf[1]
train2 = df.iloc[result2[0]]
test2 =  df.iloc[result2[1]]

result3 = listakf[2]
train3 = df.iloc[result3[0]]
test3 =  df.iloc[result3[1]]
result4 = listakf[3]
train4 = df.iloc[result4[0]]
test4 =  df.iloc[result4[1]]

# %%
train.shape
# Out:
# (27429, 11)

# %%
from sklearn.model_selection import train_test_split

x = train[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = train[['Severitate def', 'Severitate inc.','Pozitie']]

x_test = test[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y_test = test[['Severitate def', 'Severitate inc.','Pozitie']]

x2 = train2[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y2 = train2[['Severitate def', 'Severitate inc.','Pozitie']]

x2_test = test2[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y2_test = test2[['Severitate def', 'Severitate inc.','Pozitie']]

x3 = train3[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y3 = train3[['Severitate def', 'Severitate inc.','Pozitie']]

x3_test = test3[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y3_test = test3[['Severitate def', 'Severitate inc.','Pozitie']]

x4 = train4[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y4 = train4[['Severitate def', 'Severitate inc.','Pozitie']]

x4_test = test4[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y4_test = test4[['Severitate def', 'Severitate inc.','Pozitie']]



#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2)

#x_comp_train, x_comp_test, y_comp_train, y_comp_test = train_test_split(x_comp, y_comp, test_size=.2)

# %%
batch_size= 2000
ds_train = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)
ds_test = tf.data.Dataset.from_tensor_slices((x_test,y_test)).batch(batch_size)

ds_train_2 = tf.data.Dataset.from_tensor_slices((x2,y2)).batch(batch_size)
ds_test_2 = tf.data.Dataset.from_tensor_slices((x2_test,y2_test)).batch(batch_size)

ds_train_3 = tf.data.Dataset.from_tensor_slices((x3,y3)).batch(batch_size)
ds_test_3 = tf.data.Dataset.from_tensor_slices((x3_test,y3_test)).batch(batch_size)

ds_train_4 = tf.data.Dataset.from_tensor_slices((x4,y4)).batch(batch_size)
ds_test_4 = tf.data.Dataset.from_tensor_slices((x4_test,y4_test)).batch(batch_size)

#ds_comp_train = tf.data.Dataset.from_tensor_slices((x_comp_train,y_comp_train)).batch(batch_size)
#ds_comp_test = tf.data.Dataset.from_tensor_slices((x_comp,y_comp)).batch(batch_size)
# Out:
# Metal device set to: Apple M1
# 2022-06-15 19:38:33.620794: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-15 19:38:33.620897: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#df['Freq 1    f1 [Hz]'] = df['Freq 1    f1 [Hz]'].astype(float, errors = 'raise')
df.dtypes
# Out:
# Pozitie            float64
# Severitate def     float64
# Severitate inc.    float64
# Mod 1              float64
# Mod 2              float64
# Mod 3              float64
# Mod 4              float64
# Mod 5              float64
# Mod 6              float64
# Mod 7              float64
# Mod 8              float64
# dtype: object

# %% [markdown]
# # Fold 1

# %%
f = ltn.Function.MLP(input_shapes=[8],output_shape=[3],hidden_layer_sizes=(100,100,50))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.78445
# 2022-06-15 19:38:34.468091: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-15 19:38:34.468147: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train, 
        ds_test, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 5000

modelul = train(
    EPOCHS,
    metrics_dict,
    ds_train,
    ds_test,
    train_step,
    test_step,
    csv_path="kfold_4/regression_results_kfold4_1.csv",
    track_metrics=200
)
# Out:
# 2022-06-15 19:38:34.711023: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 19:38:35.326242: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 19:38:35.535298: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 19:38:35.679644: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.8605, test_sat: 0.8797, train_accuracy: 0.2061, test_accuracy: 0.1636
# Epoch 200, train_sat: 0.9527, test_sat: 0.9569, train_accuracy: 0.0630, test_accuracy: 0.0569
# Epoch 400, train_sat: 0.9579, test_sat: 0.9613, train_accuracy: 0.0568, test_accuracy: 0.0497
# Epoch 600, train_sat: 0.9560, test_sat: 0.9663, train_accuracy: 0.0607, test_accuracy: 0.0424
# Epoch 800, train_sat: 0.9686, test_sat: 0.9649, train_accuracy: 0.0416, test_accuracy: 0.0441
# Epoch 1000, train_sat: 0.9790, test_sat: 0.9800, train_accuracy: 0.0294, test_accuracy: 0.0249
# Epoch 1200, train_sat: 0.9729, test_sat: 0.9781, train_accuracy: 0.0375, test_accuracy: 0.0268
# Epoch 1400, train_sat: 0.9848, test_sat: 0.9832, train_accuracy: 0.0196, test_accuracy: 0.0210
# Epoch 1600, train_sat: 0.9825, test_sat: 0.9816, train_accuracy: 0.0223, test_accuracy: 0.0241
# Epoch 1800, train_sat: 0.9834, test_sat: 0.9829, train_accuracy: 0.0218, test_accuracy: 0.0219
# Epoch 2000, train_sat: 0.9840, test_sat: 0.9867, train_accuracy: 0.0204, test_accuracy: 0.0175
# Epoch 2200, train_sat: 0.9710, test_sat: 0.9632, train_accuracy: 0.0371, test_accuracy: 0.0462
# Epoch 2400, train_sat: 0.9829, test_sat: 0.9854, train_accuracy: 0.0219, test_accuracy: 0.0188
# Epoch 2600, train_sat: 0.9820, test_sat: 0.9745, train_accuracy: 0.0225, test_accuracy: 0.0312
# Epoch 2800, train_sat: 0.9774, test_sat: 0.9804, train_accuracy: 0.0298, test_accuracy: 0.0251
# Epoch 3000, train_sat: 0.9796, test_sat: 0.9817, train_accuracy: 0.0265, test_accuracy: 0.0231
# Epoch 3200, train_sat: 0.9791, test_sat: 0.9781, train_accuracy: 0.0262, test_accuracy: 0.0274
# Epoch 3400, train_sat: 0.9814, test_sat: 0.9762, train_accuracy: 0.0232, test_accuracy: 0.0290
# Epoch 3600, train_sat: 0.9817, test_sat: 0.9842, train_accuracy: 0.0228, test_accuracy: 0.0204
# Epoch 3800, train_sat: 0.9853, test_sat: 0.9837, train_accuracy: 0.0189, test_accuracy: 0.0206
# Epoch 4000, train_sat: 0.9846, test_sat: 0.9851, train_accuracy: 0.0192, test_accuracy: 0.0185
# Epoch 4200, train_sat: 0.9800, test_sat: 0.9677, train_accuracy: 0.0249, test_accuracy: 0.0392
# Epoch 4400, train_sat: 0.9790, test_sat: 0.9816, train_accuracy: 0.0263, test_accuracy: 0.0222
# Epoch 4600, train_sat: 0.9689, test_sat: 0.9790, train_accuracy: 0.0423, test_accuracy: 0.0259
# Epoch 4800, train_sat: 0.9843, test_sat: 0.9824, train_accuracy: 0.0202, test_accuracy: 0.0223

# %%
import seaborn as sns
sns.set(font_scale=1.2)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("kfold_4/LTN_regresie_kfold4_1_1.png")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("kfold_4/LTN_regresie_kfold4_1_2.png")
plt.show()

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/date_test_corectate.csv", on_bad_lines='skip')

# %%
df = df.sample(frac=1) #shuffle
x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Severitate def', 'Severitate inc.','Pozitie']]
batch_size= 32
ds_test = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

data = {'y_pred':[],'y_true':[],'def':[],'inc':[],'Mod 1':[],'Mod 2':[],'Mod 3':[],'Mod 4':[],'Mod 5':[],'Mod 6':[],'Mod 7':[],'Mod 8':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
    data['def'].extend(y[:,0].numpy())
    data['inc'].extend(y[:,1].numpy())
    data['Mod 1'].extend(x[:,0].numpy())
    data['Mod 2'].extend(x[:,1].numpy())
    data['Mod 3'].extend(x[:,2].numpy())
    data['Mod 4'].extend(x[:,3].numpy())
    data['Mod 5'].extend(x[:,4].numpy())
    data['Mod 6'].extend(x[:,5].numpy())
    data['Mod 7'].extend(x[:,6].numpy())
    data['Mod 8'].extend(x[:,7].numpy())
#'Severitate def', 'Severitate inc.'

# %%
data_plot = pd.DataFrame(data,columns=['y_pred','y_true','def','inc','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8'])

# %%
dif =data_plot["y_true"] - data_plot["y_pred"]

# %%
plt.stem(dif)
plt.xlabel("Predicted values", size = "20")
plt.ylabel("Residuals", size = "20")
plt.savefig("kfold_4/residuals_kfold4_1.png")

# %%
from openpyxl import Workbook
# !pip install openpyxl
data_plot.to_excel("kfold_4/output_kfold4_1.xlsx")
# Out:
# Requirement already satisfied: openpyxl in /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# # Fold 2

# %%
f = ltn.Function.MLP(input_shapes=[8],output_shape=[3],hidden_layer_sizes=(100,100,50))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test_2:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.78611
# 2022-06-15 20:06:19.028005: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train_2, 
        ds_test_2, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train_2:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test_2:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 5000

modelul2 = train(
    EPOCHS,
    metrics_dict,
    ds_train_2,
    ds_test_2,
    train_step,
    test_step,
    csv_path="kfold_4/regression_results_kfold4_2.csv",
    track_metrics=200
)
# Out:
# 2022-06-15 20:06:19.364727: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 20:06:19.844535: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 20:06:20.029488: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 20:06:20.143951: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.8603, test_sat: 0.8800, train_accuracy: 0.2067, test_accuracy: 0.1628
# Epoch 200, train_sat: 0.9553, test_sat: 0.9580, train_accuracy: 0.0596, test_accuracy: 0.0549
# Epoch 400, train_sat: 0.9573, test_sat: 0.9540, train_accuracy: 0.0574, test_accuracy: 0.0595
# Epoch 600, train_sat: 0.9676, test_sat: 0.9708, train_accuracy: 0.0409, test_accuracy: 0.0370
# Epoch 800, train_sat: 0.9783, test_sat: 0.9738, train_accuracy: 0.0273, test_accuracy: 0.0324
# Epoch 1000, train_sat: 0.9723, test_sat: 0.9757, train_accuracy: 0.0366, test_accuracy: 0.0311
# Epoch 1200, train_sat: 0.9804, test_sat: 0.9803, train_accuracy: 0.0248, test_accuracy: 0.0248
# Epoch 1400, train_sat: 0.9814, test_sat: 0.9784, train_accuracy: 0.0232, test_accuracy: 0.0281
# Epoch 1600, train_sat: 0.9736, test_sat: 0.9772, train_accuracy: 0.0361, test_accuracy: 0.0297
# Epoch 1800, train_sat: 0.9770, test_sat: 0.9732, train_accuracy: 0.0311, test_accuracy: 0.0351
# Epoch 2000, train_sat: 0.9827, test_sat: 0.9849, train_accuracy: 0.0219, test_accuracy: 0.0196
# Epoch 2200, train_sat: 0.9754, test_sat: 0.9782, train_accuracy: 0.0316, test_accuracy: 0.0273
# Epoch 2400, train_sat: 0.9786, test_sat: 0.9852, train_accuracy: 0.0271, test_accuracy: 0.0190
# Epoch 2600, train_sat: 0.9802, test_sat: 0.9840, train_accuracy: 0.0252, test_accuracy: 0.0212
# Epoch 2800, train_sat: 0.9799, test_sat: 0.9732, train_accuracy: 0.0253, test_accuracy: 0.0346
# Epoch 3000, train_sat: 0.9842, test_sat: 0.9840, train_accuracy: 0.0201, test_accuracy: 0.0205
# Epoch 3200, train_sat: 0.9787, test_sat: 0.9748, train_accuracy: 0.0261, test_accuracy: 0.0317
# Epoch 3400, train_sat: 0.9783, test_sat: 0.9770, train_accuracy: 0.0292, test_accuracy: 0.0305
# Epoch 3600, train_sat: 0.9853, test_sat: 0.9831, train_accuracy: 0.0188, test_accuracy: 0.0218
# Epoch 3800, train_sat: 0.9816, test_sat: 0.9843, train_accuracy: 0.0232, test_accuracy: 0.0207
# Epoch 4000, train_sat: 0.9872, test_sat: 0.9843, train_accuracy: 0.0166, test_accuracy: 0.0200
# Epoch 4200, train_sat: 0.9818, test_sat: 0.9842, train_accuracy: 0.0229, test_accuracy: 0.0206
# Epoch 4400, train_sat: 0.9866, test_sat: 0.9848, train_accuracy: 0.0175, test_accuracy: 0.0198
# Epoch 4600, train_sat: 0.9850, test_sat: 0.9899, train_accuracy: 0.0198, test_accuracy: 0.0145
# Epoch 4800, train_sat: 0.9859, test_sat: 0.9810, train_accuracy: 0.0177, test_accuracy: 0.0252

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train_2:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test_2:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("kfold_4/LTN_regresie_kfold4_2_1.png")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("kfold_4/LTN_regresie_kfold4_2_2.png")
plt.show()

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/date_test_corectate.csv", on_bad_lines='skip')

# %%
df = df.sample(frac=1) #shuffle
x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Severitate def', 'Severitate inc.','Pozitie']]
batch_size= 32
ds_test = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

data = {'y_pred':[],'y_true':[],'def':[],'inc':[],'Mod 1':[],'Mod 2':[],'Mod 3':[],'Mod 4':[],'Mod 5':[],'Mod 6':[],'Mod 7':[],'Mod 8':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
    data['def'].extend(y[:,0].numpy())
    data['inc'].extend(y[:,1].numpy())
    data['Mod 1'].extend(x[:,0].numpy())
    data['Mod 2'].extend(x[:,1].numpy())
    data['Mod 3'].extend(x[:,2].numpy())
    data['Mod 4'].extend(x[:,3].numpy())
    data['Mod 5'].extend(x[:,4].numpy())
    data['Mod 6'].extend(x[:,5].numpy())
    data['Mod 7'].extend(x[:,6].numpy())
    data['Mod 8'].extend(x[:,7].numpy())
#'Severitate def', 'Severitate inc.'

# %%
data_plot = pd.DataFrame(data,columns=['y_pred','y_true','def','inc','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8'])

# %%
dif =data_plot["y_true"] - data_plot["y_pred"]

# %%
plt.stem(dif)
plt.xlabel("Predicted values", size = "20")
plt.ylabel("Residuals", size = "20")
plt.savefig("kfold_4/residuals_kfold4_2.png")

# %%
from openpyxl import Workbook
# !pip install openpyxl
data_plot.to_excel("kfold_4/output_kfold4_2.xlsx")
# Out:
# Requirement already satisfied: openpyxl in /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# # Fold 3

# %%
f = ltn.Function.MLP(input_shapes=[8],output_shape=[3],hidden_layer_sizes=(100,100,50))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test_3:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.78545
# 2022-06-15 20:33:53.221591: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train_3, 
        ds_test_3, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train_3:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test_3:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 5000

modelul3 = train(
    EPOCHS,
    metrics_dict,
    ds_train_3,
    ds_test_3,
    train_step,
    test_step,
    csv_path="kfold_4/regression_results_kfold4_3.csv",
    track_metrics=200
)
# Out:
# 2022-06-15 20:33:53.573011: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 20:33:54.050843: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 20:33:54.229469: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 20:33:54.347716: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.8600, test_sat: 0.8782, train_accuracy: 0.2077, test_accuracy: 0.1657
# Epoch 200, train_sat: 0.9522, test_sat: 0.9485, train_accuracy: 0.0636, test_accuracy: 0.0697
# Epoch 400, train_sat: 0.9664, test_sat: 0.9598, train_accuracy: 0.0440, test_accuracy: 0.0521
# Epoch 600, train_sat: 0.9704, test_sat: 0.9646, train_accuracy: 0.0376, test_accuracy: 0.0443
# Epoch 800, train_sat: 0.9737, test_sat: 0.9798, train_accuracy: 0.0341, test_accuracy: 0.0254
# Epoch 1000, train_sat: 0.9763, test_sat: 0.9760, train_accuracy: 0.0313, test_accuracy: 0.0319
# Epoch 1200, train_sat: 0.9812, test_sat: 0.9848, train_accuracy: 0.0241, test_accuracy: 0.0193
# Epoch 1400, train_sat: 0.9840, test_sat: 0.9860, train_accuracy: 0.0204, test_accuracy: 0.0175
# Epoch 1600, train_sat: 0.9815, test_sat: 0.9828, train_accuracy: 0.0236, test_accuracy: 0.0211
# Epoch 1800, train_sat: 0.9805, test_sat: 0.9834, train_accuracy: 0.0247, test_accuracy: 0.0204
# Epoch 2000, train_sat: 0.9844, test_sat: 0.9841, train_accuracy: 0.0201, test_accuracy: 0.0195
# Epoch 2200, train_sat: 0.9732, test_sat: 0.9726, train_accuracy: 0.0339, test_accuracy: 0.0339
# Epoch 2400, train_sat: 0.9780, test_sat: 0.9784, train_accuracy: 0.0292, test_accuracy: 0.0268
# Epoch 2600, train_sat: 0.9828, test_sat: 0.9834, train_accuracy: 0.0221, test_accuracy: 0.0209
# Epoch 2800, train_sat: 0.9848, test_sat: 0.9842, train_accuracy: 0.0197, test_accuracy: 0.0193
# Epoch 3000, train_sat: 0.9850, test_sat: 0.9844, train_accuracy: 0.0193, test_accuracy: 0.0203
# Epoch 3200, train_sat: 0.9849, test_sat: 0.9878, train_accuracy: 0.0192, test_accuracy: 0.0159
# Epoch 3400, train_sat: 0.9842, test_sat: 0.9837, train_accuracy: 0.0206, test_accuracy: 0.0203
# Epoch 3600, train_sat: 0.9855, test_sat: 0.9855, train_accuracy: 0.0186, test_accuracy: 0.0184
# Epoch 3800, train_sat: 0.9833, test_sat: 0.9854, train_accuracy: 0.0211, test_accuracy: 0.0190
# Epoch 4000, train_sat: 0.9845, test_sat: 0.9848, train_accuracy: 0.0198, test_accuracy: 0.0186
# Epoch 4200, train_sat: 0.9848, test_sat: 0.9763, train_accuracy: 0.0193, test_accuracy: 0.0301
# Epoch 4400, train_sat: 0.9779, test_sat: 0.9819, train_accuracy: 0.0278, test_accuracy: 0.0219
# Epoch 4600, train_sat: 0.9863, test_sat: 0.9856, train_accuracy: 0.0171, test_accuracy: 0.0178
# Epoch 4800, train_sat: 0.9760, test_sat: 0.9862, train_accuracy: 0.0348, test_accuracy: 0.0168

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train_3:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test_3:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("kfold_4/LTN_regresie_kfold4_3_1.png")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("kfold_4/LTN_regresie_kfold4_3_2.png")
plt.show()

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/date_test_corectate.csv", on_bad_lines='skip')

# %%
df = df.sample(frac=1) #shuffle
x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Severitate def', 'Severitate inc.','Pozitie']]
batch_size= 32
ds_test = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

data = {'y_pred':[],'y_true':[],'def':[],'inc':[],'Mod 1':[],'Mod 2':[],'Mod 3':[],'Mod 4':[],'Mod 5':[],'Mod 6':[],'Mod 7':[],'Mod 8':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
    data['def'].extend(y[:,0].numpy())
    data['inc'].extend(y[:,1].numpy())
    data['Mod 1'].extend(x[:,0].numpy())
    data['Mod 2'].extend(x[:,1].numpy())
    data['Mod 3'].extend(x[:,2].numpy())
    data['Mod 4'].extend(x[:,3].numpy())
    data['Mod 5'].extend(x[:,4].numpy())
    data['Mod 6'].extend(x[:,5].numpy())
    data['Mod 7'].extend(x[:,6].numpy())
    data['Mod 8'].extend(x[:,7].numpy())
#'Severitate def', 'Severitate inc.'

# %%
data_plot = pd.DataFrame(data,columns=['y_pred','y_true','def','inc','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8'])

# %%
dif =data_plot["y_true"] - data_plot["y_pred"]

# %%
plt.stem(dif)
plt.xlabel("Predicted values", size = "20")
plt.ylabel("Residuals", size = "20")
plt.savefig("kfold_4/residuals_kfold4_3.png")

# %%
from openpyxl import Workbook
# !pip install openpyxl
data_plot.to_excel("kfold_4/output_kfold4_3.xlsx")
# Out:
# Requirement already satisfied: openpyxl in /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# # Fold 4

# %%
f = ltn.Function.MLP(input_shapes=[8],output_shape=[3],hidden_layer_sizes=(100,100,50))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test_4:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.78732
# 2022-06-15 21:01:53.507184: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train_4, 
        ds_test_4, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train_4:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test_4:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 5000

modelul4 = train(
    EPOCHS,
    metrics_dict,
    ds_train_4,
    ds_test_4,
    train_step,
    test_step,
    csv_path="kfold_4/regression_results_kfold4_4.csv",
    track_metrics=200
)
# Out:
# 2022-06-15 21:01:53.846776: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 21:01:54.333830: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 21:01:54.512114: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-15 21:01:54.628703: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.8603, test_sat: 0.8790, train_accuracy: 0.2065, test_accuracy: 0.1645
# Epoch 200, train_sat: 0.9530, test_sat: 0.9559, train_accuracy: 0.0622, test_accuracy: 0.0610
# Epoch 400, train_sat: 0.9629, test_sat: 0.9672, train_accuracy: 0.0489, test_accuracy: 0.0435
# Epoch 600, train_sat: 0.9744, test_sat: 0.9676, train_accuracy: 0.0323, test_accuracy: 0.0424
# Epoch 800, train_sat: 0.9727, test_sat: 0.9699, train_accuracy: 0.0349, test_accuracy: 0.0387
# Epoch 1000, train_sat: 0.9680, test_sat: 0.9791, train_accuracy: 0.0413, test_accuracy: 0.0263
# Epoch 1200, train_sat: 0.9711, test_sat: 0.9605, train_accuracy: 0.0392, test_accuracy: 0.0539
# Epoch 1400, train_sat: 0.9804, test_sat: 0.9684, train_accuracy: 0.0248, test_accuracy: 0.0396
# Epoch 1600, train_sat: 0.9732, test_sat: 0.9656, train_accuracy: 0.0360, test_accuracy: 0.0468
# Epoch 1800, train_sat: 0.9742, test_sat: 0.9813, train_accuracy: 0.0364, test_accuracy: 0.0259
# Epoch 2000, train_sat: 0.9731, test_sat: 0.9661, train_accuracy: 0.0364, test_accuracy: 0.0482
# Epoch 2200, train_sat: 0.9844, test_sat: 0.9773, train_accuracy: 0.0197, test_accuracy: 0.0294
# Epoch 2400, train_sat: 0.9837, test_sat: 0.9784, train_accuracy: 0.0206, test_accuracy: 0.0271
# Epoch 2600, train_sat: 0.9809, test_sat: 0.9808, train_accuracy: 0.0238, test_accuracy: 0.0239
# Epoch 2800, train_sat: 0.9801, test_sat: 0.9775, train_accuracy: 0.0254, test_accuracy: 0.0274
# Epoch 3000, train_sat: 0.9815, test_sat: 0.9843, train_accuracy: 0.0241, test_accuracy: 0.0207
# Epoch 3200, train_sat: 0.9829, test_sat: 0.9838, train_accuracy: 0.0223, test_accuracy: 0.0215
# Epoch 3400, train_sat: 0.9872, test_sat: 0.9846, train_accuracy: 0.0164, test_accuracy: 0.0215
# Epoch 3600, train_sat: 0.9827, test_sat: 0.9873, train_accuracy: 0.0226, test_accuracy: 0.0169
# Epoch 3800, train_sat: 0.9766, test_sat: 0.9801, train_accuracy: 0.0315, test_accuracy: 0.0254
# Epoch 4000, train_sat: 0.9821, test_sat: 0.9887, train_accuracy: 0.0237, test_accuracy: 0.0151
# Epoch 4200, train_sat: 0.9855, test_sat: 0.9867, train_accuracy: 0.0187, test_accuracy: 0.0166
# Epoch 4400, train_sat: 0.9805, test_sat: 0.9870, train_accuracy: 0.0248, test_accuracy: 0.0169
# Epoch 4600, train_sat: 0.9808, test_sat: 0.9815, train_accuracy: 0.0237, test_accuracy: 0.0228
# Epoch 4800, train_sat: 0.9837, test_sat: 0.9737, train_accuracy: 0.0205, test_accuracy: 0.0334

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train_4:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test_4:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("kfold_4/LTN_regresie_kfold4_4_1.png")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("kfold_4/LTN_regresie_kfold4_4_2.png")
plt.show()

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/date_test_corectate.csv", on_bad_lines='skip')

# %%
df = df.sample(frac=1) #shuffle
x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Severitate def', 'Severitate inc.','Pozitie']]
batch_size= 32
ds_test = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

data = {'y_pred':[],'y_true':[],'def':[],'inc':[],'Mod 1':[],'Mod 2':[],'Mod 3':[],'Mod 4':[],'Mod 5':[],'Mod 6':[],'Mod 7':[],'Mod 8':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,2].numpy())
    data['y_true'].extend(y[:,2].numpy())
    data['def'].extend(y[:,0].numpy())
    data['inc'].extend(y[:,1].numpy())
    data['Mod 1'].extend(x[:,0].numpy())
    data['Mod 2'].extend(x[:,1].numpy())
    data['Mod 3'].extend(x[:,2].numpy())
    data['Mod 4'].extend(x[:,3].numpy())
    data['Mod 5'].extend(x[:,4].numpy())
    data['Mod 6'].extend(x[:,5].numpy())
    data['Mod 7'].extend(x[:,6].numpy())
    data['Mod 8'].extend(x[:,7].numpy())
#'Severitate def', 'Severitate inc.'

# %%
data_plot = pd.DataFrame(data,columns=['y_pred','y_true','def','inc','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8'])

# %%
dif =data_plot["y_true"] - data_plot["y_pred"]

# %%
plt.stem(dif)
plt.xlabel("Predicted values", size = "20")
plt.ylabel("Residuals", size = "20")
plt.savefig("kfold_4/residuals_kfold4_4.png")

# %%
from openpyxl import Workbook
# !pip install openpyxl
data_plot.to_excel("kfold_4/output_kfold4_4.xlsx")
# Out:
# Requirement already satisfied: openpyxl in /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from openpyxl) (1.1.0)

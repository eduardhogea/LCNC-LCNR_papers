# %%
import logging; logging.basicConfig(level=logging.INFO)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import logictensornetworks as ltn
import pandas as pd

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training_sectiune/tot.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
df_comp = df.sample(50) # un numar de valori random sa vedem acuratetea
#df.sample(5)
#df.shape
df = df.sample(int(len(df)*(100/100)))
print(df.shape)
# Out:
# (36573, 11)

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# #df = scaler.fit_transform(df)

# %%
df.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df.shape
# Out:
# Null values in dataset are 0
# (36573, 11)

# %%
df_comp.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df_comp.replace([np.inf, -np.inf], np.nan, inplace=True)
df_comp.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df_comp.shape
# Out:
# Null values in dataset are 0
# (50, 11)

# %%
from sklearn.model_selection import train_test_split


x = df[['Severitate def', 'Severitate inc.','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Pozitie']]

x_comp = df_comp[['Severitate def', 'Severitate inc.','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y_comp = df_comp[['Pozitie']]


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2)

#x_comp_train, x_comp_test, y_comp_train, y_comp_test = train_test_split(x_comp, y_comp, test_size=.2)

# %%
batch_size= 64
ds_train = tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(batch_size)
ds_test = tf.data.Dataset.from_tensor_slices((x_test,y_test)).batch(batch_size)

#ds_comp_train = tf.data.Dataset.from_tensor_slices((x_comp_train,y_comp_train)).batch(batch_size)
ds_comp_test = tf.data.Dataset.from_tensor_slices((x_comp,y_comp)).batch(batch_size)
# Out:
# Metal device set to: Apple M1
# 2022-06-10 16:00:06.147765: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-10 16:00:06.147856: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#df['Freq 1    f1 [Hz]'] = df['Freq 1    f1 [Hz]'].astype(float, errors = 'raise')
df.dtypes
# Out:
# Pozitie            float64
# Severitate def     float64
# Severitate inc.    float64
# Mod 1              float64
# Mod 2              float64
# Mod 3              float64
# Mod 4              float64
# Mod 5              float64
# Mod 6              float64
# Mod 7              float64
# Mod 8              float64
# dtype: object

# %%
f = ltn.Function.MLP(input_shapes=[10],output_shape=[1],hidden_layer_sizes=(100,100,50))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.79292
# 2022-06-10 16:00:06.852631: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-10 16:00:06.852684: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train, 
        ds_test, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 60

modelul = train(
    EPOCHS,
    metrics_dict,
    ds_train,
    ds_test,
    train_step,
    test_step,
    csv_path="testtest.csv",
    track_metrics=1
)
# Out:
# 2022-06-10 16:00:07.046193: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-10 16:00:12.193704: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-10 16:00:12.376035: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-10 16:00:12.839430: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.9113, test_sat: 0.9251, train_accuracy: 0.2135, test_accuracy: 0.1704
# Epoch 1, train_sat: 0.9395, test_sat: 0.9022, train_accuracy: 0.1407, test_accuracy: 0.2363
# Epoch 2, train_sat: 0.9474, test_sat: 0.8991, train_accuracy: 0.1224, test_accuracy: 0.2494
# Epoch 3, train_sat: 0.9521, test_sat: 0.9025, train_accuracy: 0.1125, test_accuracy: 0.2421
# Epoch 4, train_sat: 0.9536, test_sat: 0.9262, train_accuracy: 0.1092, test_accuracy: 0.1739
# Epoch 5, train_sat: 0.9576, test_sat: 0.9295, train_accuracy: 0.1001, test_accuracy: 0.1655
# Epoch 6, train_sat: 0.9599, test_sat: 0.9731, train_accuracy: 0.0932, test_accuracy: 0.0576
# Epoch 7, train_sat: 0.9634, test_sat: 0.9325, train_accuracy: 0.0857, test_accuracy: 0.1587
# Epoch 8, train_sat: 0.9660, test_sat: 0.9620, train_accuracy: 0.0788, test_accuracy: 0.0859
# Epoch 9, train_sat: 0.9662, test_sat: 0.9818, train_accuracy: 0.0793, test_accuracy: 0.0384
# Epoch 10, train_sat: 0.9668, test_sat: 0.9778, train_accuracy: 0.0781, test_accuracy: 0.0482
# Epoch 11, train_sat: 0.9684, test_sat: 0.9483, train_accuracy: 0.0743, test_accuracy: 0.1168
# Epoch 12, train_sat: 0.9683, test_sat: 0.9511, train_accuracy: 0.0733, test_accuracy: 0.1092
# Epoch 13, train_sat: 0.9704, test_sat: 0.9761, train_accuracy: 0.0681, test_accuracy: 0.0507
# Epoch 14, train_sat: 0.9693, test_sat: 0.9556, train_accuracy: 0.0723, test_accuracy: 0.0972
# Epoch 15, train_sat: 0.9714, test_sat: 0.9653, train_accuracy: 0.0673, test_accuracy: 0.0735
# Epoch 16, train_sat: 0.9732, test_sat: 0.9613, train_accuracy: 0.0630, test_accuracy: 0.0885
# Epoch 17, train_sat: 0.9707, test_sat: 0.9665, train_accuracy: 0.0679, test_accuracy: 0.0722
# Epoch 18, train_sat: 0.9722, test_sat: 0.9551, train_accuracy: 0.0656, test_accuracy: 0.0968
# Epoch 19, train_sat: 0.9736, test_sat: 0.9843, train_accuracy: 0.0614, test_accuracy: 0.0329
# Epoch 20, train_sat: 0.9747, test_sat: 0.9620, train_accuracy: 0.0576, test_accuracy: 0.0874
# Epoch 21, train_sat: 0.9745, test_sat: 0.9849, train_accuracy: 0.0591, test_accuracy: 0.0312
# Epoch 22, train_sat: 0.9745, test_sat: 0.9839, train_accuracy: 0.0593, test_accuracy: 0.0337
# Epoch 23, train_sat: 0.9706, test_sat: 0.9673, train_accuracy: 0.0689, test_accuracy: 0.0699
# Epoch 24, train_sat: 0.9753, test_sat: 0.9740, train_accuracy: 0.0576, test_accuracy: 0.0567
# Epoch 25, train_sat: 0.9745, test_sat: 0.9696, train_accuracy: 0.0600, test_accuracy: 0.0655
# Epoch 26, train_sat: 0.9746, test_sat: 0.9804, train_accuracy: 0.0590, test_accuracy: 0.0407
# Epoch 27, train_sat: 0.9754, test_sat: 0.9713, train_accuracy: 0.0583, test_accuracy: 0.0595
# Epoch 28, train_sat: 0.9783, test_sat: 0.9855, train_accuracy: 0.0498, test_accuracy: 0.0303
# Epoch 29, train_sat: 0.9780, test_sat: 0.9688, train_accuracy: 0.0522, test_accuracy: 0.0664
# Epoch 30, train_sat: 0.9784, test_sat: 0.9854, train_accuracy: 0.0505, test_accuracy: 0.0312
# Epoch 31, train_sat: 0.9766, test_sat: 0.9684, train_accuracy: 0.0547, test_accuracy: 0.0707
# Epoch 32, train_sat: 0.9767, test_sat: 0.9700, train_accuracy: 0.0542, test_accuracy: 0.0641
# Epoch 33, train_sat: 0.9776, test_sat: 0.9832, train_accuracy: 0.0519, test_accuracy: 0.0345
# Epoch 34, train_sat: 0.9785, test_sat: 0.9812, train_accuracy: 0.0490, test_accuracy: 0.0388
# Epoch 35, train_sat: 0.9790, test_sat: 0.9741, train_accuracy: 0.0496, test_accuracy: 0.0557
# Epoch 36, train_sat: 0.9779, test_sat: 0.9593, train_accuracy: 0.0519, test_accuracy: 0.0905
# Epoch 37, train_sat: 0.9782, test_sat: 0.9838, train_accuracy: 0.0510, test_accuracy: 0.0337
# Epoch 38, train_sat: 0.9790, test_sat: 0.9744, train_accuracy: 0.0489, test_accuracy: 0.0536
# Epoch 39, train_sat: 0.9803, test_sat: 0.9729, train_accuracy: 0.0458, test_accuracy: 0.0566
# Epoch 40, train_sat: 0.9789, test_sat: 0.9648, train_accuracy: 0.0499, test_accuracy: 0.0793
# Epoch 41, train_sat: 0.9789, test_sat: 0.9801, train_accuracy: 0.0512, test_accuracy: 0.0417
# Epoch 42, train_sat: 0.9794, test_sat: 0.9854, train_accuracy: 0.0485, test_accuracy: 0.0305
# Epoch 43, train_sat: 0.9791, test_sat: 0.9866, train_accuracy: 0.0486, test_accuracy: 0.0279
# Epoch 44, train_sat: 0.9807, test_sat: 0.9722, train_accuracy: 0.0452, test_accuracy: 0.0594
# Epoch 45, train_sat: 0.9805, test_sat: 0.9717, train_accuracy: 0.0448, test_accuracy: 0.0589
# Epoch 46, train_sat: 0.9792, test_sat: 0.9687, train_accuracy: 0.0484, test_accuracy: 0.0663
# Epoch 47, train_sat: 0.9803, test_sat: 0.9860, train_accuracy: 0.0460, test_accuracy: 0.0291
# Epoch 48, train_sat: 0.9819, test_sat: 0.9849, train_accuracy: 0.0434, test_accuracy: 0.0323
# Epoch 49, train_sat: 0.9810, test_sat: 0.9828, train_accuracy: 0.0444, test_accuracy: 0.0361
# Epoch 50, train_sat: 0.9818, test_sat: 0.9745, train_accuracy: 0.0430, test_accuracy: 0.0554
# Epoch 51, train_sat: 0.9812, test_sat: 0.9712, train_accuracy: 0.0444, test_accuracy: 0.0637
# Epoch 52, train_sat: 0.9815, test_sat: 0.9882, train_accuracy: 0.0431, test_accuracy: 0.0255
# Epoch 53, train_sat: 0.9821, test_sat: 0.9794, train_accuracy: 0.0419, test_accuracy: 0.0432
# Epoch 54, train_sat: 0.9831, test_sat: 0.9782, train_accuracy: 0.0394, test_accuracy: 0.0462
# Epoch 55, train_sat: 0.9828, test_sat: 0.9843, train_accuracy: 0.0407, test_accuracy: 0.0341
# Epoch 56, train_sat: 0.9832, test_sat: 0.9658, train_accuracy: 0.0395, test_accuracy: 0.0754
# Epoch 57, train_sat: 0.9825, test_sat: 0.9755, train_accuracy: 0.0410, test_accuracy: 0.0528
# Epoch 58, train_sat: 0.9833, test_sat: 0.9832, train_accuracy: 0.0389, test_accuracy: 0.0342
# Epoch 59, train_sat: 0.9835, test_sat: 0.9904, train_accuracy: 0.0382, test_accuracy: 0.0194

# %%
import seaborn as sns
sns.set(font_scale=1.2)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("LTN_regresie_1.pdf")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("LTN_regresie_2")
plt.show()

# %%
# figure, axis = plt.subplots(figsize=(12,8))
# x_ax = range(51)
# axis.plot(x_ax, data['y_true'].tail(50), label="Pozitie", color='c')
# axis.plot(x_ax, data['y_pred'].tail(50), label="Pozitie-pred", color='b')
# axis.legend()


# plt.savefig('test.pdf')  
# plt.show()

# %%
# fig, axs = plt.subplots(1,2,figsize=(12,6))
# ax = axs[0]
# data = {'y_pred':[],'y_true':[]}
# for x,y in ds_comp_train:
#     data['y_pred'].extend(f.model(x)[:,0].numpy())
#     data['y_true'].extend(y[:,0].numpy())
# df = pd.DataFrame(data,columns=['y_pred','y_true'])
# ax.set_xlim(0,80)
# ax.set_ylim(0,80)
# sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
#             scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
# ax.plot([0,100],[0,100],color="gray",linestyle="--")
# ax.set_xlabel("Actual y values")
# ax.set_ylabel("Fitted y values")
# ax.set_title("Training Data")

# # ax = axs[1]
# data = {'y_pred':[],'y_true':[]}
# for x,y in ds_comp_test:
#     data['y_pred'].extend(f.model(x)[:,0].numpy())
#     data['y_true'].extend(y[:,0].numpy())
# df = pd.DataFrame(data,columns=['y_pred','y_true'])
# ax.set_ylim(0,80)
# ax.set_xlim(0,80)
# sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
#             scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
# ax.plot([0,100],[0,100],color="gray",linestyle="--")
# ax.set_xlabel("Actual y values")
# ax.set_ylabel("Fitted y values")
# ax.set_title("Test Data")
# plt.tight_layout()
# plt.savefig("LTN_regresie_1.pdf")

# %%
# figure, axis = plt.subplots(figsize=(12,8))
# x_ax = range(50)
# axis.plot(x_ax, data['y_true'], label="Pozitie", color='c')
# axis.plot(x_ax, data['y_pred'], label="Pozitie-pred", color='b')
# axis.legend()


# plt.savefig('test_general.pdf')  
# plt.show()

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training_sectiune/tot.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
x = df[['Severitate def', 'Severitate inc.','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Pozitie']]
batch_size= 32
ds_test = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

data = {'y_pred':[],'y_true':[],'def':[],'inc':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
    data['def'].extend(x[:,0].numpy())
    data['inc'].extend(x[:,1].numpy())
data_plot = pd.DataFrame(data,columns=['y_pred','y_true','def','inc'])
#'Severitate def', 'Severitate inc.'

# %%
data_plot.head(4)
# Out:
#      y_pred  y_true       def       inc
# 0  0.169978   0.152  0.001191  0.000413
# 1  0.236144   0.218  0.012434  0.000000
# 2  0.456507   0.440  0.007105  0.000567
# 3  0.389352   0.374  0.012434  0.000000

# %%
data_plot.shape
# Out:
# (36573, 4)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

sns.scatterplot(data=data_plot, x="y_pred", y="y_true", hue="def")
plt.legend(title = 'Severitate def', fontsize='20', title_fontsize='20')
plt.xlabel("Predicted value", size=20)
plt.ylabel("Actual value", size=20)
plt.savefig("def.png")

# %%
sns.scatterplot(data=data_plot, x="y_pred", y="y_true", hue="inc")
plt.legend(title = 'Severitate incastrare', fontsize='20', title_fontsize='20')
plt.xlabel("Predicted value", size=20)
plt.ylabel("Actual value", size=20)
plt.savefig("inc.png")

# %%
data_plot['def'].unique
# Out:
# <bound method Series.unique of 0        0.001191
# 1        0.012434
# 2        0.007105
# 3        0.012434
# 4        0.007105
#            ...
# 36568    0.016030
# 36569    0.066210
# 36570    0.020444
# 36571    0.066210
# 36572    0.001191
# Name: def, Length: 36573, dtype: float64>
